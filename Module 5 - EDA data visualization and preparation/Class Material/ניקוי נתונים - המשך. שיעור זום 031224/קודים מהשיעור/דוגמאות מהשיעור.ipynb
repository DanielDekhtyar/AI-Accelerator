# %% [markdown]
# # review

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('employee.csv')

# %%
df.head(3)
# Out:
#   first_name   last_name  salary  start_date   gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020      NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020     Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020  Agender    True  engineering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   int64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 48.0+ KB

# %%
#create new column
df.insert(0,column ='bonus',value=100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bonus       1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   salary      1000 non-null   int64
#  4   start_date  976 non-null    object
#  5   gender      966 non-null    object
#  6   remote      1000 non-null   bool
#  7   team        1000 non-null   object
# dtypes: bool(1), int64(2), object(5)
# memory usage: 55.8+ KB

# %%
df.head()
# Out:
#    bonus first_name   last_name  salary  start_date    gender  remote  \
# 0    100    Haleigh  Calderhead  334473    5/9/2020       NaN    True
# 1    100    Coretta      McEvon  637457   3/20/2020      Male   False
# 2    100   Clarette     Tarbett  977749  11/22/2020   Agender    True
# 3    100      Jaime  Gianneschi  253523    9/2/2020  Bigender   False
# 4    100      Ediva     Skelton  325185    2/4/2020    Female    True
#
#           team
# 0   management
# 1  engineering
# 2  engineering
# 3    marketing
# 4    marketing

# %% [markdown]
# ### dropping a column:

# %%
df.drop('bonus',axis =1,inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   int64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 48.0+ KB

# %% [markdown]
# # Data cleaning dropna fillna isnull

# %%
df= pd.read_csv('employee_missing.csv')

# %%
df.head()
# Out:
#   first_name   last_name    salary  start_date    gender remote         team
# 0    Haleigh  Calderhead  334473.0    05-09-20       NaN   True   management
# 1    Coretta         NaN  637457.0   3/20/2020      Male  False  engineering
# 2   Clarette         NaN  977749.0  11/22/2020   Agender   True  engineering
# 3      Jaime  Gianneschi  253523.0    09-02-20  Bigender  False          NaN
# 4      Ediva     Skelton  325185.0    02-04-20    Female   True    marketing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   998 non-null    object
#  2   salary      1000 non-null   float64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   object
#  6   team        999 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 54.9+ KB

# %%
df.tail()
# Out:
#      first_name   last_name    salary  start_date       gender remote  \
# 996       Ashby  Threadgold  140806.0  12/28/2020  Genderfluid  False
# 997     Justino     Asquith  950280.0  10/26/2020  Genderqueer  False
# 998      Jerald     Penella  862555.0    09-08-20       Female  False
# 999         NaN         NaN       NaN         NaN          NaN    NaN
# 1000     Aubrie        Hunt  549364.0   3/29/2020   Polygender  False
#
#                 team
# 996       management
# 997       management
# 998      engineering
# 999              NaN
# 1000  data analytics

# %%
df.dropna(how="all", axis =0,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   998 non-null    object
#  2   salary      1000 non-null   float64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   object
#  6   team        999 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 62.5+ KB

# %%
df.dropna(subset= ['last_name'],inplace = True)

# %% [markdown]
# ---reverse to droping just one row

# %%
df.head()
# Out:
#   first_name   last_name    salary  start_date    gender remote         team
# 0    Haleigh  Calderhead  334473.0    05-09-20       NaN   True   management
# 1    Coretta         NaN  637457.0   3/20/2020      Male  False  engineering
# 2   Clarette         NaN  977749.0  11/22/2020   Agender   True  engineering
# 3      Jaime  Gianneschi  253523.0    09-02-20  Bigender  False          NaN
# 4      Ediva     Skelton  325185.0    02-04-20    Female   True    marketing

# %%
#fillna
df.fillna(0)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5980\2109752869.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0)
#      first_name   last_name    salary  start_date       gender  remote  \
# 0       Haleigh  Calderhead  334473.0    05-09-20            0    True
# 1       Coretta           0  637457.0   3/20/2020         Male   False
# 2      Clarette           0  977749.0  11/22/2020      Agender    True
# 3         Jaime  Gianneschi  253523.0    09-02-20     Bigender   False
# 4         Ediva     Skelton  325185.0    02-04-20       Female    True
# ...         ...         ...       ...         ...          ...     ...
# 995      Ysabel  Stollmeyer  649625.0  10/18/2020   Polygender   False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   998 non-null    object
#  2   salary      1000 non-null   float64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   object
#  6   team        999 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 62.5+ KB

# %%
df.fillna(0, inplace = True) #שינוי קבוע
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5980\9686392.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   float64
#  3   start_date  1000 non-null   object
#  4   gender      1000 non-null   object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 55.7+ KB

# %%
df= pd.read_csv('employee_missing.csv')
df.dropna(how="all", axis =0,inplace = True)

# %%
df.head()
# Out:
#   first_name   last_name    salary  start_date    gender remote         team
# 0    Haleigh  Calderhead  334473.0    05-09-20       NaN   True   management
# 1    Coretta         NaN  637457.0   3/20/2020      Male  False  engineering
# 2   Clarette         NaN  977749.0  11/22/2020   Agender   True  engineering
# 3      Jaime  Gianneschi  253523.0    09-02-20  Bigender  False          NaN
# 4      Ediva     Skelton  325185.0    02-04-20    Female   True    marketing

# %%
df['gender'].fillna('Agender',inplace =True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5980\2349900593.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].fillna('Agender',inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   998 non-null    object
#  2   salary      1000 non-null   float64
#  3   start_date  976 non-null    object
#  4   gender      1000 non-null   object
#  5   remote      1000 non-null   object
#  6   team        999 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 62.5+ KB

# %%
df['salary'].describe()
# Out:
# count      1000.000000
# mean     545343.075000
# std      255394.561799
# min      100752.000000
# 25%      334175.750000
# 50%      537517.500000
# 75%      764956.250000
# max      997426.000000
# Name: salary, dtype: float64

# %%
#isnull
df= pd.read_csv('employee_missing.csv')
df.dropna(how="all", axis =0,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   998 non-null    object
#  2   salary      1000 non-null   float64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   object
#  6   team        999 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 62.5+ KB

# %%
df['gender'].isnull()
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 995     False
# 996     False
# 997     False
# 998     False
# 1000    False
# Name: gender, Length: 1000, dtype: bool

# %%
df['gender'].isnull().head(11)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# Name: gender, dtype: bool

# %%
df.head(10)
# Out:
#    first_name     last_name    salary  start_date      gender remote  \
# 0     Haleigh    Calderhead  334473.0    05-09-20         NaN   True
# 1     Coretta           NaN  637457.0   3/20/2020        Male  False
# 2    Clarette           NaN  977749.0  11/22/2020     Agender   True
# 3       Jaime    Gianneschi  253523.0    09-02-20    Bigender  False
# 4       Ediva       Skelton  325185.0    02-04-20      Female   True
# 5     Auberta  Whistlecraft  510781.0         NaN  Polygender  False
# 6     Devland     Cominetti  194815.0   1/16/2021    Bigender  False
# 7       Sarah       Feather  553617.0    04-05-20         NaN   True
# 8  Andromache        McAviy  562931.0   9/15/2020  Non-binary   True
# 9     Susanna      Ivachyov  873134.0  11/19/2020     Agender  False
#
#              team
# 0      management
# 1     engineering
# 2     engineering
# 3             NaN
# 4       marketing
# 5     engineering
# 6     engineering
# 7  data analytics
# 8      management
# ...

# %%
df['gender'].head(5)
# Out:
# 0         NaN
# 1        Male
# 2     Agender
# 3    Bigender
# 4      Female
# Name: gender, dtype: object

# %%
mask = df['gender'].isnull()

#df[df['gender'].isnull()]

# %%
df[mask]
# Out:
#      first_name     last_name    salary  start_date gender remote  \
# 0       Haleigh    Calderhead  334473.0    05-09-20    NaN   True
# 7         Sarah       Feather  553617.0    04-05-20    NaN   True
# 10         Gray     Ghirigori  972661.0   5/29/2020    NaN  False
# 11      Malissa       Billett  492837.0    09-01-20    NaN  False
# 68     Ursuline      Surfleet  631021.0    08-11-20    NaN   True
# 84       Cecile   Jerzycowski  987315.0   9/23/2020    NaN   True
# 119        Mike  Sommerscales  264558.0  12/26/2020    NaN  False
# 129       Hyman           Bye  758704.0  10/29/2020    NaN  False
# 138       Randa        Visick  114061.0    05-04-20    NaN  False
# 143      Hamnet       Wipfler  284895.0    05-05-20    NaN  False
# 173       Carma       Matejka  882031.0   4/30/2020    NaN   True
# 201       Datha        Leyban  256662.0   2/16/2020    NaN  False
# 336    Bernette     Scrigmour  591366.0    08-11-20    NaN   True
# ...

# %%
df.head(10)
# Out:
#    first_name     last_name    salary  start_date      gender remote  \
# 0     Haleigh    Calderhead  334473.0    05-09-20         NaN   True
# 1     Coretta           NaN  637457.0   3/20/2020        Male  False
# 2    Clarette           NaN  977749.0  11/22/2020     Agender   True
# 3       Jaime    Gianneschi  253523.0    09-02-20    Bigender  False
# 4       Ediva       Skelton  325185.0    02-04-20      Female   True
# 5     Auberta  Whistlecraft  510781.0         NaN  Polygender  False
# 6     Devland     Cominetti  194815.0   1/16/2021    Bigender  False
# 7       Sarah       Feather  553617.0    04-05-20         NaN   True
# 8  Andromache        McAviy  562931.0   9/15/2020  Non-binary   True
# 9     Susanna      Ivachyov  873134.0  11/19/2020     Agender  False
#
#              team
# 0      management
# 1     engineering
# 2     engineering
# 3             NaN
# 4       marketing
# 5     engineering
# 6     engineering
# 7  data analytics
# 8      management
# ...

# %%
mask=df['last_name'].isnull()

# %%
df[mask]
# Out:
#   first_name last_name    salary  start_date   gender remote         team
# 1    Coretta       NaN  637457.0   3/20/2020     Male  False  engineering
# 2   Clarette       NaN  977749.0  11/22/2020  Agender   True  engineering
