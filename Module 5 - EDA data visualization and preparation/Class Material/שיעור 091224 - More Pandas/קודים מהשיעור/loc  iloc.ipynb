# %%
import pandas as pd
cereal = pd.read_csv('cereal.csv')

# %%
cereal.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
cereal.tail(10)
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 67                Special K   K    C       110        6    0     230    1.0
# 68  Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# 69        Total Corn Flakes   G    C       110        2    1     200    0.0
# 70        Total Raisin Bran   G    C       140        3    1     190    4.0
# 71        Total Whole Grain   G    C       100        3    1     200    3.0
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
cereal = pd.read_csv('cereal.csv', index_col = "name")

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.6+ KB

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.sort_index(inplace = True)

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal = pd.read_csv('cereal.csv')

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.set_index(keys = "name", inplace =Tr)

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.6+ KB

# %%
cereal.sort_index(inplace =True)

# %%
cereal.reset_index(inplace = True)

# %%
cereal.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
cereal = pd.read_csv('cereal.csv')
cereal.set_index(keys = "name", inplace =True)

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.reset_index(inplace = True, drop = True)

# %%
cereal.head()
# Out:
#   mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0   N    C        70        4    1     130   10.0    5.0       6     280
# 1   Q    C       120        3    5      15    2.0    8.0       8     135
# 2   K    C        70        4    1     260    9.0    7.0       5     320
# 3   K    C        50        4    0     140   14.0    8.0       0     330
# 4   R    C       110        2    2     200    1.0   14.0       8      -1
#
#    vitamins  shelf  weight  cups     rating
# 0        25      3     1.0  0.33  68.402973
# 1         0      3     1.0  1.00  33.983679
# 2        25      3     1.0  0.33  59.425505
# 3        25      3     1.0  0.50  93.704912
# 4        25      3     1.0  0.75  34.384843

# %%
# resting to start:
cereal = pd.read_csv('cereal.csv', index_col = "name")
cereal.sort_index(inplace =True)

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.6+ KB

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.loc["Almond Delight"]
# Out:
# mfr                 R
# type                C
# calories          110
# protein             2
# fat                 2
# sodium            200
# fiber             1.0
# carbo            14.0
# sugars              8
# potass             -1
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.75
# rating      34.384843
# Name: Almond Delight, dtype: object

# %%
emps = pd.read_csv('employee.csv')

# %%
emps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   int64
#  3   start_date  976 non-null    object
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 48.0+ KB

# %%
emps.head()
# Out:
#   first_name   last_name  salary  start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020       NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020      Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020   Agender    True  engineering
# 3      Jaime  Gianneschi  253523    9/2/2020  Bigender   False    marketing
# 4      Ediva     Skelton  325185    2/4/2020    Female    True    marketing

# %%
emps.loc[3]
# Out:
# first_name         Jaime
# last_name     Gianneschi
# salary            253523
# start_date      9/2/2020
# gender          Bigender
# remote             False
# team           marketing
# Name: 3, dtype: object

# %%
cereal.loc["Lion"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lion'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#cereal.loc["Almond Delight"]  # the same as:
cereal[cereal.index == "Almond Delight"]
# Out:
#                mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Almond Delight   R    C       110        2    2     200    1.0   14.0       8
#
#                 potass  vitamins  shelf  weight  cups     rating
# name
# Almond Delight      -1        25      3     1.0  0.75  34.384843

# %%
cereal.head(15)
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# Apple Jacks                 K    C       110        2    0     125    1.0
# Basic 4                     G    C       130        3    2     210    2.0
# Bran Chex                   R    C        90        2    1     200    4.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Cap'n'Crunch                Q    C       120        1    2     220    0.0
# Cheerios                    G    C       110        6    2     290    2.0
# ...

# %%
cereal.loc["Apple Jacks":"Cheerios"]
# Out:
#              mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Apple Jacks    K    C       110        2    0     125    1.0   11.0      14
# Basic 4        G    C       130        3    2     210    2.0   18.0       8
# Bran Chex      R    C        90        2    1     200    4.0   15.0       6
# Bran Flakes    P    C        90        3    0     210    5.0   13.0       5
# Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0      12
# Cheerios       G    C       110        6    2     290    2.0   17.0       1
#
#               potass  vitamins  shelf  weight  cups     rating
# name
# Apple Jacks       30        25      2    1.00  1.00  33.174094
# Basic 4          100        25      3    1.33  0.75  37.038562
# Bran Chex        125        25      1    1.00  0.67  49.120253
# Bran Flakes      190        25      3    1.00  0.67  53.313813
# Cap'n'Crunch      35        25      2    1.00  0.75  18.042851
# ...

# %%
cereal.loc["Apple Jacks":"Cheerios":2]
# Out:
#              mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Apple Jacks    K    C       110        2    0     125    1.0   11.0      14
# Bran Chex      R    C        90        2    1     200    4.0   15.0       6
# Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0      12
#
#               potass  vitamins  shelf  weight  cups     rating
# name
# Apple Jacks       30        25      2     1.0  1.00  33.174094
# Bran Chex        125        25      1     1.0  0.67  49.120253
# Cap'n'Crunch      35        25      2     1.0  0.75  18.042851

# %%
cereal.loc["Cheerios":"Apple Jacks"]
# Out:
# Empty DataFrame
# Columns: [mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating]
# Index: []

# %%
cereal.loc["Cheerios":"Apple Jacks":-1]
# Out:
#              mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Cheerios       G    C       110        6    2     290    2.0   17.0       1
# Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0      12
# Bran Flakes    P    C        90        3    0     210    5.0   13.0       5
# Bran Chex      R    C        90        2    1     200    4.0   15.0       6
# Basic 4        G    C       130        3    2     210    2.0   18.0       8
# Apple Jacks    K    C       110        2    0     125    1.0   11.0      14
#
#               potass  vitamins  shelf  weight  cups     rating
# name
# Cheerios         105        25      1    1.00  1.25  50.764999
# Cap'n'Crunch      35        25      2    1.00  0.75  18.042851
# Bran Flakes      190        25      3    1.00  0.67  53.313813
# Bran Chex        125        25      1    1.00  0.67  49.120253
# Basic 4          100        25      3    1.33  0.75  37.038562
# ...

# %%
emps.loc[10:20:2]
# Out:
#    first_name   last_name  salary start_date       gender  remote  \
# 10       Gray   Ghirigori  972661  5/29/2020          NaN   False
# 12       Dani  Withinshaw  152136  11/8/2020  Genderfluid    True
# 14     Alfred     Paraman  234494  1/19/2021       Female   False
# 16      Wylma       Cowey  254555  11/8/2020     Bigender   False
# 18       Free    Prangley  385983  9/12/2020  Genderfluid    True
# 20      Doria     Ladyman  223628  11/3/2020         Male    True
#
#               team
# 10       marketing
# 12  data analytics
# 14  data analytics
# 16       marketing
# 18     engineering
# 20       marketing

# %%
cereal.loc[::-1]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Trix                        G    C       110        1    1     140    0.0
# Triples                     G    C       110        2    1     250    0.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Almond Delight              R    C       110        2    2     200    1.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# All-Bran                    K    C        70        4    1     260    9.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# 100% Bran                   N    C        70        4    1     130   10.0
#
# ...

# %%
cereal.loc[::7]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# Basic 4                     G    C       130        3    2     210    2.0
# Cocoa Puffs                 G    C       110        1    1     180    0.0
# Crispix                     K    C       110        2    0     220    1.0
# Fruitful Bran               K    C       120        3    0     240    5.0
# Honey Graham Ohs            Q    C       120        1    2     220    1.0
# Lucky Charms                G    C       110        2    1     180    0.0
# Nutri-Grain Almond-Raisin   K    C       140        3    2     220    3.0
# Quaker Oat Squares          Q    C       100        4    1     135    2.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Total Raisin Bran           G    C       140        3    1     190    4.0
#
# ...

# %%
cereal.loc[::]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
cereal.loc[:, "type"]
# Out:
# name
# 100% Bran                    C
# 100% Natural Bran            C
# All-Bran                     C
# All-Bran with Extra Fiber    C
# Almond Delight               C
#                             ..
# Triples                      C
# Trix                         C
# Wheat Chex                   C
# Wheaties                     C
# Wheaties Honey Gold          C
# Name: type, Length: 77, dtype: object

# %%
cereal ["type"]
# Out:
# name
# 100% Bran                    C
# 100% Natural Bran            C
# All-Bran                     C
# All-Bran with Extra Fiber    C
# Almond Delight               C
#                             ..
# Triples                      C
# Trix                         C
# Wheat Chex                   C
# Wheaties                     C
# Wheaties Honey Gold          C
# Name: type, Length: 77, dtype: object

# %%
cereal.loc[:,["protein","rating"]]
#cereal[["protein","rating"]]
# Out:
#                            protein     rating
# name
# 100% Bran                        4  68.402973
# 100% Natural Bran                3  33.983679
# All-Bran                         4  59.425505
# All-Bran with Extra Fiber        4  93.704912
# Almond Delight                   2  34.384843
# ...                            ...        ...
# Triples                          2  39.106174
# Trix                             1  27.753301
# Wheat Chex                       3  49.787445
# Wheaties                         3  51.592193
# Wheaties Honey Gold              2  36.187559
#
# [77 rows x 2 columns]

# %%
cereal.loc[:,["rating","protein"]]
# Out:
#                               rating  protein
# name
# 100% Bran                  68.402973        4
# 100% Natural Bran          33.983679        3
# All-Bran                   59.425505        4
# All-Bran with Extra Fiber  93.704912        4
# Almond Delight             34.384843        2
# ...                              ...      ...
# Triples                    39.106174        2
# Trix                       27.753301        1
# Wheat Chex                 49.787445        3
# Wheaties                   51.592193        3
# Wheaties Honey Gold        36.187559        2
#
# [77 rows x 2 columns]

# %%
cereal.loc["Smacks",["calories", "sugars"]]
# Out:
# calories    110
# sugars       15
# Name: Smacks, dtype: object

# %%
cereal.loc["Apple Jacks":"Cheerios":2, ["sugars","rating"]]
# Out:
#               sugars     rating
# name
# Apple Jacks       14  33.174094
# Bran Chex          6  49.120253
# Cap'n'Crunch      12  18.042851

# %%
cereal.head(20)
#cereal.iloc[1]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# Apple Jacks                 K    C       110        2    0     125    1.0
# Basic 4                     G    C       130        3    2     210    2.0
# Bran Chex                   R    C        90        2    1     200    4.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Cap'n'Crunch                Q    C       120        1    2     220    0.0
# Cheerios                    G    C       110        6    2     290    2.0
# ...

# %%
cereal.iloc[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10836\1707451397.py in <module>
# ----> 1 cereal.iloc[100]
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
# ...

# %%
cereal.loc["lion"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lion'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
cereal.iloc[-1]
# Out:
# mfr                 G
# type                C
# calories          110
# protein             2
# fat                 1
# sodium            200
# fiber             1.0
# carbo            16.0
# sugars              8
# potass             60
# vitamins           25
# shelf               1
# weight            1.0
# cups             0.75
# rating      36.187559
# Name: Wheaties Honey Gold, dtype: object

# %%
cereal.iloc[0:20:3]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Apple Jacks                 K    C       110        2    0     125    1.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Cinnamon Toast Crunch       G    C       120        1    3     210    0.0
# Corn Chex                   R    C       110        2    0     280    0.0
# Count Chocula               G    C       110        1    1     180    0.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Apple Jacks                 11.0      14      30        25      2     1.0
# ...

# %%
cereal.iloc[::10]
# Out:
#                        mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran                N    C        70        4    1     130   10.0    5.0
# Cap'n'Crunch             Q    C       120        1    2     220    0.0   12.0
# Cream of Wheat (Quick)   N    H       100        3    0      80    1.0   21.0
# Golden Crisp             P    C       100        2    0      45    0.0   11.0
# Kix                      G    C       110        2    1     260    0.0   21.0
# Nutri-grain Wheat        K    C        90        3    0     170    3.0   18.0
# Raisin Squares           K    C        90        2    0       0    2.0   15.0
# Total Raisin Bran        G    C       140        3    1     190    4.0   15.0
#
#                         sugars  potass  vitamins  shelf  weight  cups  \
# name
# 100% Bran                    6     280        25      3     1.0  0.33
# Cap'n'Crunch                12      35        25      2     1.0  0.75
# ...

# %%
cereal.iloc[[0,9,65]]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# Bran Flakes                 13.0       5     190        25      3     1.0
# Shredded Wheat spoon size   20.0       0     120         0      1     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# Bran Flakes                0.67  53.313813
# Shredded Wheat spoon size  0.67  72.801787

# %%
cereal.loc[["Shredded Wheat spoon size","100% Bran"]]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 100% Bran                   N    C        70        4    1     130   10.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# Shredded Wheat spoon size   20.0       0     120         0      1     1.0
# 100% Bran                    5.0       6     280        25      3     1.0
#
#                            cups     rating
# name
# Shredded Wheat spoon size  0.67  72.801787
# 100% Bran                  0.33  68.402973

# %%
cereal.iloc[14].name
# Out:
# 'Cocoa Puffs'

# %%
emps.iloc[3].name
# Out:
# 3

# %%
cereal.iloc[:,1]
# Out:
# name
# 100% Bran                    C
# 100% Natural Bran            C
# All-Bran                     C
# All-Bran with Extra Fiber    C
# Almond Delight               C
#                             ..
# Triples                      C
# Trix                         C
# Wheat Chex                   C
# Wheaties                     C
# Wheaties Honey Gold          C
# Name: type, Length: 77, dtype: object

# %%
cereal.iloc[:,[1]]
# Out:
#                           type
# name
# 100% Bran                    C
# 100% Natural Bran            C
# All-Bran                     C
# All-Bran with Extra Fiber    C
# Almond Delight               C
# ...                        ...
# Triples                      C
# Trix                         C
# Wheat Chex                   C
# Wheaties                     C
# Wheaties Honey Gold          C
#
# [77 rows x 1 columns]

# %%
cereal.iloc[[66,67],[4,14]]
# Out:
#            fat     rating
# name
# Smacks       1  31.230054
# Special K    0  53.131324

# %%
cereal.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.iloc[4,9]
# Out:
# -1

# %%
cereal.loc["Almond Delight","potass"]
# Out:
# -1

# %%
cereal.loc["Almond Delight","potass"] =1

# %%
cereal.loc["Almond Delight","potass"]
# Out:
# 1

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8       1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.loc["All-Bran","calories":]=0

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C         0        0    0       0    0.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     0.0       0       0         0      0     0.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8       1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
ctype= cereal["type"]== "C"

# %%
ctype
# Out:
# name
# 100% Bran                    True
# 100% Natural Bran            True
# All-Bran                     True
# All-Bran with Extra Fiber    True
# Almond Delight               True
#                              ...
# Triples                      True
# Trix                         True
# Wheat Chex                   True
# Wheaties                     True
# Wheaties Honey Gold          True
# Name: type, Length: 77, dtype: bool

# %%
cereal.loc[ctype]["type"]= "cold"
# Out:
# C:\Users\AiFTW\.conda\envs\env_2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C         0        0    0       0    0.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     0.0       0       0         0      0     0.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8       1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
ctype= cereal["type"]== "C"
cereal.loc[ctype,"type"]="cold"

# %%
cereal.head()
# Out:
#                           mfr  type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  cold        70        4    1     130   10.0
# 100% Natural Bran           Q  cold       120        3    5      15    2.0
# All-Bran                    K  cold         0        0    0       0    0.0
# All-Bran with Extra Fiber   K  cold        50        4    0     140   14.0
# Almond Delight              R  cold       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     0.0       0       0         0      0     0.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8       1        25      3     1.0
#
#                            cups     rating
# name
# ...
