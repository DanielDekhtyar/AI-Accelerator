# %%
import pandas as pd

# %%
emps = pd.read_csv('employee.csv')

# %%
emps['start_date'] = pd.to_datetime(emps['start_date'] format ="mixed")

# %%
emps.head()
# Out:
#   first_name   last_name  salary  start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020       NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020      Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020   Agender    True  engineering
# 3      Jaime  Gianneschi  253523    9/2/2020  Bigender   False    marketing
# 4      Ediva     Skelton  325185    2/4/2020    Female    True    marketing

# %%
emps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   int64
#  3   start_date  976 non-null    datetime64[ns]
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 48.0+ KB

# %%
mask_low = emps['salary']> 599067
mask_h = emps['salary']< 600000
emps[mask_low & mask_h].sort_values('salary')
# Out:
#     first_name    last_name  salary start_date      gender  remote  \
# 28    Carmella        Pacht  599103 2020-06-05  Non-binary   False
# 880     Wanids      Gillett  599912 2020-08-15     Agender    True
# 563     Graham  Thunnerclef  599917 2020-09-11  Polygender   False
#
#                team
# 28   data analytics
# 880       marketing
# 563      management

# %%
mask_3 = emps['salary'].between(599067, 599917)

# %%
emps[mask_3]
# Out:
#     first_name    last_name  salary start_date       gender  remote  \
# 28    Carmella        Pacht  599103 2020-06-05   Non-binary   False
# 563     Graham  Thunnerclef  599917 2020-09-11   Polygender   False
# 655    Gwyneth  Abramowitch  599067 2020-09-24  Genderqueer    True
# 880     Wanids      Gillett  599912 2020-08-15      Agender    True
#
#                team
# 28   data analytics
# 563      management
# 655     engineering
# 880       marketing

# %%
mask_4 = emps['salary'].between( 599917,599067)
emps[mask_4]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, salary, start_date, gender, remote, team]
# Index: []

# %%
mask_date = emps['start_date'].between('2020-08-01', '2020-08-06')

# %%
emps[mask_date].shape[0]
# Out:
# 8

# %%
mask_5 = emps['first_name'].between('Alice','Bob')

# %%
emps[mask_5].sort_values('first_name')
# Out:
#     first_name  last_name  salary start_date       gender  remote  \
# 767      Alice    Demeter  593256 2021-01-21       Female    True
# 309     Alikee    Gleeson  254767 2020-11-22  Genderqueer    True
# 462    Allegra    Fargher  938158 2021-01-04  Genderqueer   False
# 356      Alley  Aitcheson  257771 2020-07-05       Female   False
# 262  Allianora      Kuban  485137 2020-05-11         Male    True
# ..         ...        ...     ...        ...          ...     ...
# 901      Binny    Keuneke  334201 2020-04-11   Polygender    True
# 425     Birdie     Dennis  755410 2020-03-11  Genderqueer    True
# 153     Blaire   Denisard  983101 2020-07-28      Agender    True
# 42      Blithe   Circuitt  987183 2020-08-11   Polygender   False
# 456     Blithe        Gay  338102 2020-02-09         Male    True
#
#                team
# 767       marketing
# 309      management
# 462     engineering
# 356     engineering
# 262       marketing
# ..              ...
# 901  data analytics
# ...

# %%
mask_gender = emps["gender"].isna()
mask_nn = emps["gender"].notna()

# %%
emps[mask_nn]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva       Skelton  325185 2020-02-04       Female    True
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# ..         ...           ...     ...        ...          ...     ...
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 998     Jerald       Penella  862555 2020-09-08       Female   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# 5       engineering
# ...

# %%
 emps2 = pd.read_csv('employee_dup.csv', parse_dates = ['start_date'])

# %%
emps2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   int64
#  3   start_date  976 non-null    datetime64[ns]
#  4   gender      964 non-null    object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 48.0+ KB

# %%
emps2.head()
# Out:
#   first_name   last_name  salary start_date    gender  remote        team
# 0    Haleigh  Calderhead  334473 2020-05-09       NaN    True  management
# 1    Haleigh  Calderhead  334473 2020-05-09       NaN    True  management
# 2    Haleigh  Calderhead  334473 2020-05-09       NaN    True  management
# 3      Jaime  Gianneschi  253523 2020-09-02  Bigender   False   marketing
# 4      Jaime  Gianneschi  253523 2020-09-02  Bigender   False   marketing

# %%
emps2.duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
emps2.duplicated(keep= "last")
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
mask = emps2.duplicated(keep= "last")
emps2[~mask] #rows that will stay
emps[mask]#rows that will be droped
# Out:
#   first_name   last_name  salary start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473 2020-05-09       NaN    True   management
# 1    Coretta      McEvon  637457 2020-03-20      Male   False  engineering
# 3      Jaime  Gianneschi  253523 2020-09-02  Bigender   False    marketing

# %%
emps2.duplicated(keep= False)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
emps2['first_name'].duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: first_name, Length: 1000, dtype: bool

# %%
emps2['first_name'].duplicated().sort_values().tail()
# Out:
# 371    True
# 758    True
# 161    True
# 110    True
# 719    True
# Name: first_name, dtype: bool

# %%
emps2['first_name'].sort_values().tail()
# Out:
# 550    Zachary
# 540       Zara
# 675    Zebulon
# 476       Zita
# 783       Zita
# Name: first_name, dtype: object

# %%
emps2.drop_duplicates(keep= False)
# Out:
#      first_name     last_name  salary start_date       gender  remote  \
# 5       Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6       Devland     Cominetti  194815 2021-01-16     Bigender   False
# 7         Sarah       Feather  553617 2020-04-05          NaN    True
# 8    Andromache        McAviy  562931 2020-09-15   Non-binary    True
# 9       Susanna      Ivachyov  873134 2020-11-19      Agender   False
# ..          ...           ...     ...        ...          ...     ...
# 995      Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996       Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997     Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 998      Jerald       Penella  862555 2020-09-08       Female   False
# 999      Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 5       engineering
# 6       engineering
# 7    data analytics
# 8        management
# ...

# %%
#how many will be deleted
emps2.shape[0] - emps2.drop_duplicates().shape[0]
# Out:
# 3

# %%
emps2.drop_duplicates()
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473 2020-05-09          NaN    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16     Bigender   False
# 7        Sarah       Feather  553617 2020-04-05          NaN    True
# ..         ...           ...     ...        ...          ...     ...
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 998     Jerald       Penella  862555 2020-09-08       Female   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 3         marketing
# 5       engineering
# 6       engineering
# 7    data analytics
# ...

# %%
emps2.duplicated().sum()
# Out:
# 3

# %%
emps2.drop_duplicates(keep= "last", inplace =True)

# %%
emps2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 2 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  997 non-null    object
#  1   last_name   997 non-null    object
#  2   salary      997 non-null    int64
#  3   start_date  973 non-null    datetime64[ns]
#  4   gender      963 non-null    object
#  5   remote      997 non-null    bool
#  6   team        997 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 55.5+ KB

# %%
emps2 = pd.read_csv('employee_dup.csv', parse_dates = ['start_date'])

# %%
emps2.sort_values('first_name',inplace =True)

# %%
emps2.head()
# Out:
#     first_name last_name  salary start_date      gender  remote  \
# 619      Aaron     Pohls  188614 2021-01-29        Male    True
# 872      Aaron   Caddens  583629 2020-10-05      Female    True
# 74        Abbi      Waby  433227 2020-04-13  Polygender    True
# 535       Abby    August  280480 2020-08-10  Polygender    True
# 898    Adaline   Cohalan  260075 2020-07-30  Polygender    True
#
#                team
# 619       marketing
# 872       marketing
# 74        marketing
# 535  data analytics
# 898     engineering

# %%
emps2.tail()
# Out:
#     first_name last_name  salary start_date       gender  remote  \
# 550    Zachary    Herity  925381 2020-10-23   Non-binary   False
# 540       Zara    Carbin  848862 2021-01-26   Non-binary    True
# 675    Zebulon  Lattimer  933655 2020-07-25         Male    True
# 476       Zita   Bewicke  198218 2020-12-11       Female    True
# 783       Zita    Follos  891648 2020-10-09  Genderqueer   False
#
#                team
# 550  data analytics
# 540  data analytics
# 675     engineering
# 476  data analytics
# 783       marketing

# %%
#emps2 = emps2.drop_duplicates() #duplicated rows X
#emps2 = emps2['first_name'].drop_duplicates() #returs Series

# %%
emps2 = emps2.drop_duplicates("first_name")

# %%
emps2.head()
# Out:
#     first_name last_name  salary start_date       gender  remote  \
# 619      Aaron     Pohls  188614 2021-01-29         Male    True
# 74        Abbi      Waby  433227 2020-04-13   Polygender    True
# 535       Abby    August  280480 2020-08-10   Polygender    True
# 898    Adaline   Cohalan  260075 2020-07-30   Polygender    True
# 47       Adara     Wakes  727063 2020-05-04  Genderfluid   False
#
#                team
# 619       marketing
# 74        marketing
# 535  data analytics
# 898     engineering
# 47       management

# %%
emps2.tail()
# Out:
# 586     Yvette
# 550    Zachary
# 540       Zara
# 675    Zebulon
# 476       Zita
# Name: first_name, dtype: object
