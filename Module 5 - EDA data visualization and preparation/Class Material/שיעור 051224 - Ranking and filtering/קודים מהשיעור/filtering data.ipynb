# %%
import pandas as pd

# %%
df = pd.read_csv('employee.csv', parse_dates = ['start_date'])

# %%
1==2
# Out:
# False

# %%
2==2
# Out:
# True

# %%
~df['gender'].isnull()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
mask = df['gender'].isnull()

# %%
df[mask]
# Out:
#      first_name     last_name  salary start_date gender  remote  \
# 0       Haleigh    Calderhead  334473 2020-05-09    NaN    True
# 7         Sarah       Feather  553617 2020-04-05    NaN    True
# 10         Gray     Ghirigori  972661 2020-05-29    NaN   False
# 11      Malissa       Billett  492837 2020-09-01    NaN   False
# 68     Ursuline      Surfleet  631021 2020-08-11    NaN    True
# 84       Cecile   Jerzycowski  987315 2020-09-23    NaN    True
# 119        Mike  Sommerscales  264558 2020-12-26    NaN   False
# 129       Hyman           Bye  758704 2020-10-29    NaN   False
# 138       Randa        Visick  114061 2020-05-04    NaN   False
# 143      Hamnet       Wipfler  284895 2020-05-05    NaN   False
# 173       Carma       Matejka  882031 2020-04-30    NaN    True
# 201       Datha        Leyban  256662 2020-02-16    NaN   False
# 336    Bernette     Scrigmour  591366 2020-08-11    NaN    True
# 351        Kory          Hovy  426422 2020-10-05    NaN    True
# ...

# %%
df[df['gender'].isnull()]
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 0      Haleigh  Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta      McEvon  637457 2020-03-20         Male   False
# 2     Clarette     Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime  Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva     Skelton  325185 2020-02-04       Female    True
# ..         ...         ...     ...        ...          ...     ...
# 995     Ysabel  Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby  Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino     Asquith  950280 2020-10-26  Genderqueer   False
# 998     Jerald     Penella  862555 2020-09-08       Female   False
# 999     Aubrie        Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# ...

# %%
df.head()
# Out:
#   first_name   last_name  salary start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473 2020-05-09       NaN    True   management
# 1    Coretta      McEvon  637457 2020-03-20      Male   False  engineering
# 2   Clarette     Tarbett  977749 2020-11-22   Agender    True  engineering
# 3      Jaime  Gianneschi  253523 2020-09-02  Bigender   False    marketing
# 4      Ediva     Skelton  325185 2020-02-04    Female    True    marketing

# %%
df['team'] =='engineering'
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: team, Length: 1000, dtype: bool

# %%
df[df['team'] =='engineering']
# Out:
#     first_name     last_name  salary start_date      gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20        Male   False
# 2     Clarette       Tarbett  977749 2020-11-22     Agender    True
# 5      Auberta  Whistlecraft  510781        NaT  Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16    Bigender   False
# 9      Susanna      Ivachyov  873134 2020-11-19     Agender   False
# ..         ...           ...     ...        ...         ...     ...
# 972    Kennett   Franzonello  580290 2020-07-07  Non-binary    True
# 973        Ola        Dautry  804650 2020-08-20     Agender    True
# 977      Theda        Sharpe  739171 2020-05-29    Bigender    True
# 988     Ariana   Culverhouse  901497 2020-12-04      Female   False
# 998     Jerald       Penella  862555 2020-09-08      Female   False
#
#             team
# 1    engineering
# 2    engineering
# 5    engineering
# 6    engineering
# 9    engineering
# ..           ...
# 972  engineering
# ...

# %%
condition = df['team'] =='engineering'
df[condition]
# Out:
#     first_name     last_name  salary start_date      gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20        Male   False
# 2     Clarette       Tarbett  977749 2020-11-22     Agender    True
# 5      Auberta  Whistlecraft  510781        NaT  Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16    Bigender   False
# 9      Susanna      Ivachyov  873134 2020-11-19     Agender   False
# ..         ...           ...     ...        ...         ...     ...
# 972    Kennett   Franzonello  580290 2020-07-07  Non-binary    True
# 973        Ola        Dautry  804650 2020-08-20     Agender    True
# 977      Theda        Sharpe  739171 2020-05-29    Bigender    True
# 988     Ariana   Culverhouse  901497 2020-12-04      Female   False
# 998     Jerald       Penella  862555 2020-09-08      Female   False
#
#             team
# 1    engineering
# 2    engineering
# 5    engineering
# 6    engineering
# 9    engineering
# ..           ...
# 972  engineering
# ...

# %%
df['gender'] =='Female'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df['gender'] =='Female']
# Out:
#     first_name    last_name  salary start_date  gender  remote            team
# 4        Ediva      Skelton  325185 2020-02-04  Female    True       marketing
# 14      Alfred      Paraman  234494 2021-01-19  Female   False  data analytics
# 46       Ernst   Fishbourne  994191 2020-10-10  Female    True  data analytics
# 65       Ivory    MacMaster  848465 2020-10-06  Female   False      management
# 86      Ingmar       Cuesta  254625 2020-10-29  Female   False      management
# ..         ...          ...     ...        ...     ...     ...             ...
# 983       Niki       Ivanin  132578 2020-10-27  Female   False       marketing
# 984     Carney        Blore  551939 2020-05-06  Female   False      management
# 988     Ariana  Culverhouse  901497 2020-12-04  Female   False     engineering
# 992        Roy     Axworthy  597997 2020-08-25  Female   False       marketing
# 998     Jerald      Penella  862555 2020-09-08  Female   False     engineering
#
# [129 rows x 7 columns]

# %%
mask =df['gender'] =='Female'
df[mask]
# Out:
#     first_name    last_name  salary start_date  gender  remote            team
# 4        Ediva      Skelton  325185 2020-02-04  Female    True       marketing
# 14      Alfred      Paraman  234494 2021-01-19  Female   False  data analytics
# 46       Ernst   Fishbourne  994191 2020-10-10  Female    True  data analytics
# 65       Ivory    MacMaster  848465 2020-10-06  Female   False      management
# 86      Ingmar       Cuesta  254625 2020-10-29  Female   False      management
# ..         ...          ...     ...        ...     ...     ...             ...
# 983       Niki       Ivanin  132578 2020-10-27  Female   False       marketing
# 984     Carney        Blore  551939 2020-05-06  Female   False      management
# 988     Ariana  Culverhouse  901497 2020-12-04  Female   False     engineering
# 992        Roy     Axworthy  597997 2020-08-25  Female   False       marketing
# 998     Jerald      Penella  862555 2020-09-08  Female   False     engineering
#
# [129 rows x 7 columns]

# %%
mask =df['gender'] !='Female'
df[mask]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# ..         ...           ...     ...        ...          ...     ...
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 5       engineering
# ...

# %%
mask = ~(df['gender'] =='Female')
df[mask]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# ..         ...           ...     ...        ...          ...     ...
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 5       engineering
# ...

# %%
mask =df['gender'] =='Female'
df[~mask]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# ..         ...           ...     ...        ...          ...     ...
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 5       engineering
# ...

# %%
mask =df['gender'] =='Female'
df[~ mask]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# ..         ...           ...     ...        ...          ...     ...
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 5       engineering
# ...

# %%
mask_sal = df['salary'] > 977749
df[mask_sal].sort_values('salary')
# Out:
#     first_name    last_name  salary start_date       gender  remote  \
# 158   Consuelo      Dearnly  979201 2020-06-15  Genderqueer   False
# 794     Bonnee     McGougan  979482 2020-06-26   Polygender   False
# 633   Pearline        Petti  981252 2020-03-01   Polygender    True
# 549       Esme      Ference  981671 2020-08-22  Genderqueer   False
# 596   Kristine      Ruberry  981863 2020-05-25       Female   False
# 153     Blaire     Denisard  983101 2020-07-28      Agender    True
# 369     Carmon     Paddison  983876 2020-06-09  Genderfluid   False
# 75     Antonia       Kemery  986028 2020-09-19  Genderqueer    True
# 251     Eberto       Loweth  986711 2020-06-27  Genderqueer   False
# 42      Blithe     Circuitt  987183 2020-08-11   Polygender   False
# 84      Cecile  Jerzycowski  987315 2020-09-23          NaN    True
# 903    Mathian        Artus  987505 2020-04-04     Bigender   False
# 66   Isabelita      Giorgio  988088 2020-04-21     Bigender    True
# ...

# %%
mask_sal = df['salary'] > 977749
df[~mask_sal].sort_values('salary')
# Out:
#     first_name  last_name  salary start_date      gender  remote  \
# 334      Brody   Ragsdale  100752 2021-01-10    Bigender   False
# 199        Dot  Barnbrook  103660 2020-03-13        Male   False
# 487    Maridel      Demke  105860 2020-06-05      Female   False
# 455       Egan     Dollin  105905 2020-03-07     Agender   False
# 929     Sergei      Karpe  107330 2020-06-23  Non-binary    True
# ..         ...        ...     ...        ...         ...     ...
# 583     Miguel     Monery  973243 2021-01-08      Female   False
# 953     Ondrea  Philipson  974123 2020-10-06  Polygender   False
# 591  Maddalena  Iacobacci  976129 2020-06-18        Male    True
# 234     Yolane  Woolcocks  977267 2020-12-18     Agender   False
# 2     Clarette    Tarbett  977749 2020-11-22     Agender    True
#
#                team
# 334      management
# 199      management
# 487       marketing
# 455      management
# 929       marketing
# ..              ...
# 583  data analytics
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   salary      1000 non-null   int64
#  3   start_date  976 non-null    datetime64[ns]
#  4   gender      966 non-null    object
#  5   remote      1000 non-null   bool
#  6   team        1000 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 48.0+ KB

# %%
mask_date = df['start_date'] <= '2020-03-20'
df[mask_date]
# Out:
#      first_name     last_name  salary start_date      gender  remote  \
# 1       Coretta        McEvon  637457 2020-03-20        Male   False
# 4         Ediva       Skelton  325185 2020-02-04      Female    True
# 32        Reina        Jenner  883961 2020-02-27  Non-binary    True
# 34      Julieta  Falconbridge  111472 2020-02-04  Polygender   False
# 43      Marlene     Snozzwell  449428 2020-03-17  Polygender   False
# ..          ...           ...     ...        ...         ...     ...
# 941      Nollie         McKew  306533 2020-02-24    Bigender   False
# 951      Tyrone        Duffie  392867 2020-02-03  Polygender    True
# 956  Sutherland      Loadwick  120513 2020-02-12  Polygender   False
# 966      Markos     Breazeall  300336 2020-02-27  Polygender   False
# 986      Audrie   Muddicliffe  274804 2020-02-16         NaN   False
#
#                team
# 1       engineering
# 4         marketing
# 32   data analytics
# 34   data analytics
# 43      engineering
# ...

# %%
df['remote']
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: remote, Length: 1000, dtype: bool

# %%
df[df['remote']]
# Out:
#      first_name    last_name  salary start_date      gender  remote  \
# 0       Haleigh   Calderhead  334473 2020-05-09         NaN    True
# 2      Clarette      Tarbett  977749 2020-11-22     Agender    True
# 4         Ediva      Skelton  325185 2020-02-04      Female    True
# 7         Sarah      Feather  553617 2020-04-05         NaN    True
# 8    Andromache       McAviy  562931 2020-09-15  Non-binary    True
# ..          ...          ...     ...        ...         ...     ...
# 979         Nan      McMahon  472899 2020-04-08     Agender    True
# 982       Reeta        Nurse  447882 2020-08-20        Male    True
# 985    Antonius  Rickardsson  291223 2020-09-24  Non-binary    True
# 989       Wilma      Raittie  382770 2020-10-15  Non-binary    True
# 991     Brandyn     Sprowles  654535 2020-09-06  Non-binary    True
#
#                team
# 0        management
# 2       engineering
# 4         marketing
# 7    data analytics
# 8        management
# ..              ...
# ...

# %%
df[~df['remote']]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16     Bigender   False
# 9      Susanna      Ivachyov  873134 2020-11-19      Agender   False
# ..         ...           ...     ...        ...          ...     ...
# 995     Ysabel    Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby    Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino       Asquith  950280 2020-10-26  Genderqueer   False
# 998     Jerald       Penella  862555 2020-09-08       Female   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 1       engineering
# 3         marketing
# 5       engineering
# 6       engineering
# 9       engineering
# ...

# %%
df['team'].isin(['engineering','data analytics'])
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999     True
# Name: team, Length: 1000, dtype: bool

# %%
condition = df['team'].isin(['engineering','data analytics'])
df[condition]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16     Bigender   False
# 7        Sarah       Feather  553617 2020-04-05          NaN    True
# ..         ...           ...     ...        ...          ...     ...
# 991    Brandyn      Sprowles  654535 2020-09-06   Non-binary    True
# 993      Jenny    Ballentime  741738 2020-05-20     Bigender   False
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 998     Jerald       Penella  862555 2020-09-08       Female   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 1       engineering
# 2       engineering
# 5       engineering
# 6       engineering
# 7    data analytics
# ...

# %%
df['team'].str.contains('data', case= False, na=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: team, Length: 1000, dtype: bool

# %%
mask_like =df['team'].str.contains('data', case= False, na=False)
df[mask_like]
# Out:
#     first_name   last_name  salary start_date       gender  remote  \
# 7        Sarah     Feather  553617 2020-04-05          NaN    True
# 12        Dani  Withinshaw  152136 2020-11-08  Genderfluid    True
# 14      Alfred     Paraman  234494 2021-01-19       Female   False
# 28    Carmella       Pacht  599103 2020-06-05   Non-binary   False
# 29     Hershel    Bernasek  435872 2020-09-04     Bigender   False
# ..         ...         ...     ...        ...          ...     ...
# 987    Huntlee     Fortman  329453 2020-09-25     Bigender   False
# 991    Brandyn    Sprowles  654535 2020-09-06   Non-binary    True
# 993      Jenny  Ballentime  741738 2020-05-20     Bigender   False
# 994       Myra    Bidewell  908477 2020-08-07  Genderfluid   False
# 999     Aubrie        Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 7    data analytics
# 12   data analytics
# 14   data analytics
# 28   data analytics
# 29   data analytics
# ..              ...
# ...

# %%
mask_like =df['first_name'].str.contains('s', case= False, na=False)
df[mask_like]
# Out:
#     first_name    last_name  salary start_date       gender  remote  \
# 7        Sarah      Feather  553617 2020-04-05          NaN    True
# 9      Susanna     Ivachyov  873134 2020-11-19      Agender   False
# 11     Malissa      Billett  492837 2020-09-01          NaN   False
# 29     Hershel     Bernasek  435872 2020-09-04     Bigender   False
# 37     Sharity   Aizikowitz  856634 2020-04-30  Genderfluid    True
# ..         ...          ...     ...        ...          ...     ...
# 980       Esra        Rozea  380935 2020-06-02  Genderfluid   False
# 985   Antonius  Rickardsson  291223 2020-09-24   Non-binary    True
# 995     Ysabel   Stollmeyer  649625 2020-10-18   Polygender   False
# 996      Ashby   Threadgold  140806 2020-12-28  Genderfluid   False
# 997    Justino      Asquith  950280 2020-10-26  Genderqueer   False
#
#                team
# 7    data analytics
# 9       engineering
# 11       management
# 29   data analytics
# 37   data analytics
# ..              ...
# ...

# %%
mask1= df['team'] == 'engineering'
mask2=df['team'] == 'data analytics'

df[mask1 | mask2]

df[(df['team'] == 'engineering' )| (df['team'] == 'data analytics')]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16     Bigender   False
# 7        Sarah       Feather  553617 2020-04-05          NaN    True
# ..         ...           ...     ...        ...          ...     ...
# 991    Brandyn      Sprowles  654535 2020-09-06   Non-binary    True
# 993      Jenny    Ballentime  741738 2020-05-20     Bigender   False
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 998     Jerald       Penella  862555 2020-09-08       Female   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 1       engineering
# 2       engineering
# 5       engineering
# 6       engineering
# 7    data analytics
# ...

# %%
mask1= df['team'] == 'engineering'
mask_sal = df['salary'] > 977749

df[mask1 | mask_sal ].head(15)
# Out:
#    first_name     last_name  salary start_date       gender  remote  \
# 1     Coretta        McEvon  637457 2020-03-20         Male   False
# 2    Clarette       Tarbett  977749 2020-11-22      Agender    True
# 5     Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6     Devland     Cominetti  194815 2021-01-16     Bigender   False
# 9     Susanna      Ivachyov  873134 2020-11-19      Agender   False
# 18       Free      Prangley  385983 2020-09-12  Genderfluid    True
# 22      Vonni       Bysaker  642502 2020-11-22   Non-binary   False
# 23    Hoebart         Eates  508366 2020-12-06  Genderfluid   False
# 25     Barbee         Reisk  139269 2020-05-04   Polygender    True
# 38      Nicky       Kirimaa  245975 2020-12-14  Genderfluid   False
# 41      Gavin       Meugens  144726 2020-05-30  Genderqueer   False
# 42     Blithe      Circuitt  987183 2020-08-11   Polygender   False
# 43    Marlene     Snozzwell  449428 2020-03-17   Polygender   False
# ...

# %%
df[mask1 & mask_sal ]
# Out:
#     first_name last_name  salary start_date       gender  remote         team
# 549       Esme   Ference  981671 2020-08-22  Genderqueer   False  engineering
# 890      Morly  Sheppard  994723 2021-01-16   Non-binary   False  engineering
# 903    Mathian     Artus  987505 2020-04-04     Bigender   False  engineering

# %%
mask1 = df['start_date'] >= '2021-01-01'
mask2 = df['team'] =='data analytics'
mask3 = df['salary'] > 96000

df[mask1 & mask2 & mask3]
# Out:
#      first_name      last_name  salary start_date       gender  remote  \
# 14       Alfred        Paraman  234494 2021-01-19       Female   False
# 146      Clarey         Burnie  390753 2021-01-27       Female    True
# 194      Carlos      Trethowan  573157 2021-01-12  Genderfluid    True
# 268     Barthel        Baroche  847409 2021-01-11   Polygender    True
# 286      Glynda         Greson  366521 2021-01-01   Non-binary   False
# 329     Korella         Cowitz  240279 2021-01-24     Bigender    True
# 366       Hilly        Midgley  515714 2021-01-07         Male    True
# 409        Maxy         Sudlow  303183 2021-01-21         Male    True
# 507        Derk         Huzzey  729717 2021-01-14  Genderfluid   False
# 518   Christyna        Ivashov  699506 2021-01-04     Bigender   False
# 530        Nari        Ondrich  718061 2021-01-18   Polygender   False
# 540        Zara         Carbin  848862 2021-01-26   Non-binary    True
# ...

# %%
mask1 = df['start_date'] >= '2021-01-01'
mask3 = df['salary'] > 1000000

df[mask1 | mask3]
# Out:
#      first_name      last_name  salary start_date       gender  remote  \
# 6       Devland      Cominetti  194815 2021-01-16     Bigender   False
# 13        Garik     Massingham  378504 2021-01-21  Genderfluid    True
# 14       Alfred        Paraman  234494 2021-01-19       Female   False
# 50   Cassaundra         Knevet  511076 2021-01-20         Male   False
# 53     Cordelie         Godsal  970651 2021-01-28     Bigender   False
# ..          ...            ...     ...        ...          ...     ...
# 912       Dyane         Keward  386992 2021-01-06     Bigender   False
# 931      Finlay          Crews  419210 2021-01-24  Genderfluid   False
# 942  Kristoforo  Lindenstrauss  427075 2021-01-05     Bigender   False
# 944      Marlyn      Crowcroft  148106 2021-01-24   Polygender    True
# 948      Nellie         Paulot  960906 2021-01-17   Non-binary    True
#
#                team
# 6       engineering
# 13       management
# 14   data analytics
# 50      engineering
# ...

# %%
df[mask1 & ~mask3]
# Out:
#      first_name      last_name  salary start_date       gender  remote  \
# 6       Devland      Cominetti  194815 2021-01-16     Bigender   False
# 13        Garik     Massingham  378504 2021-01-21  Genderfluid    True
# 14       Alfred        Paraman  234494 2021-01-19       Female   False
# 50   Cassaundra         Knevet  511076 2021-01-20         Male   False
# 53     Cordelie         Godsal  970651 2021-01-28     Bigender   False
# ..          ...            ...     ...        ...          ...     ...
# 912       Dyane         Keward  386992 2021-01-06     Bigender   False
# 931      Finlay          Crews  419210 2021-01-24  Genderfluid   False
# 942  Kristoforo  Lindenstrauss  427075 2021-01-05     Bigender   False
# 944      Marlyn      Crowcroft  148106 2021-01-24   Polygender    True
# 948      Nellie         Paulot  960906 2021-01-17   Non-binary    True
#
#                team
# 6       engineering
# 13       management
# 14   data analytics
# 50      engineering
# ...

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
# 5         0       3                                    Mr. James Moran
# 6         0       1                             Mr. Timothy J McCarthy
# 7         0       3                      Master. Gosta Leonard Palsson
# 8         1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9         1       2                 Mrs. Nicholas (Adele Achem) Nasser
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# ...

# %%
titanic['Sex'].nunique()
# Out:
# 2

# %%
titanic['Sex']=='female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 882    False
# 883     True
# 884     True
# 885    False
# 886    False
# Name: Sex, Length: 887, dtype: bool

# %%
titanic['Sex']= titanic['Sex']=='female'

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    bool
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: bool(1), float64(2), int64(4), object(1)
# memory usage: 49.5+ KB

# %%
mask_age= titanic ['Age'] <1

# %%
titanic[mask_age]
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 77          1       2    Master. Alden Gates Caldwell    male  0.83
# 303         1       1   Master. Hudson Trevor Allison    male  0.92
# 466         1       3    Miss. Helene Barbara Baclini  female  0.75
# 641         1       3           Miss. Eugenie Baclini  female  0.75
# 751         1       2        Master. Viljo Hamalainen    male  0.67
# 799         1       3  Master. Assad Alexander Thomas    male  0.42
# 827         1       2  Master. George Sibley Richards    male  0.83
#
#      Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# 77                         0                        2   29.0000
# 303                        1                        2  151.5500
# 466                        2                        1   19.2583
# 641                        2                        1   19.2583
# 751                        1                        1   14.5000
# ...

# %%
mask_gender = titanic['Sex']== 'male'

# %%
titanic[mask_gender]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
titanic [(~mask_gender) & mask_age   ]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, Siblings/Spouses Aboard, Parents/Children Aboard, Fare]
# Index: []
