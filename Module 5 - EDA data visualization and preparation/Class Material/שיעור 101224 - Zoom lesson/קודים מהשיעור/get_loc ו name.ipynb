# %%
import pandas as pd

# %%
emps =  pd.read_csv('oracle_emps.csv')

# %%
emps
# Out:
#     employee_id first_name   last_name     email  phone_number   hire_date  \
# 0           100     Steven        King     SKING  515.123.4567  1987-06-17
# 1           101      Neena     Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 2           102        Lex     De Haan   LDEHAAN  515.123.4569  1993-01-13
# 3           103  Alexander      Hunold   AHUNOLD  590.423.4567  1990-01-03
# 4           104      Bruce       Ernst    BERNST  590.423.4568  1991-05-21
# 5           105      David      Austin   DAUSTIN  590.423.4569  1997-06-25
# 6           106      Valli   Pataballa  VPATABAL  590.423.4560  1998-02-05
# 7           107      Diana     Lorentz  DLORENTZ  590.423.5567  1999-02-07
# 8           114        Den    Raphaely  DRAPHEAL  515.127.4561  1994-12-07
# 9           115  Alexander        Khoo     AKHOO  515.127.4562  1995-05-18
# 10          116     Shelli       Baida    SBAIDA  515.127.4563  1997-12-24
# ...

# %%
emps.duplicated('first_name').sum()
# Out:
# 1

# %%
emps.set_index('first_name', inplace= True)

# %%
emps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, Steven to Karen
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     14 non-null     int64
#  1   last_name       14 non-null     object
#  2   email           14 non-null     object
#  3   phone_number    14 non-null     object
#  4   hire_date       14 non-null     object
#  5   job_id          14 non-null     object
#  6   salary          14 non-null     float64
#  7   commission_pct  0 non-null      float64
#  8   manager_id      13 non-null     float64
#  9   department_id   14 non-null     int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 1.2+ KB

# %%
emps.sort_index(inplace = True)

# %%
emps
# Out:
#             employee_id   last_name     email  phone_number   hire_date  \
# first_name
# Alexander           103      Hunold   AHUNOLD  590.423.4567  1990-01-03
# Alexander           115        Khoo     AKHOO  515.127.4562  1995-05-18
# Bruce               104       Ernst    BERNST  590.423.4568  1991-05-21
# David               105      Austin   DAUSTIN  590.423.4569  1997-06-25
# Den                 114    Raphaely  DRAPHEAL  515.127.4561  1994-12-07
# Diana               107     Lorentz  DLORENTZ  590.423.5567  1999-02-07
# Guy                 118      Himuro   GHIMURO  515.127.4565  1998-11-15
# Karen               119  Colmenares  KCOLMENA  515.127.4566  1999-08-10
# Lex                 102     De Haan   LDEHAAN  515.123.4569  1993-01-13
# Neena               101     Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# Shelli              116       Baida    SBAIDA  515.127.4563  1997-12-24
# Sigal               117      Tobias   STOBIAS  515.127.4564  1997-07-24
# ...

# %%
emps.loc["Guy"]
# Out:
# employee_id                118
# last_name               Himuro
# email                  GHIMURO
# phone_number      515.127.4565
# hire_date           1998-11-15
# job_id                PU_CLERK
# salary                  2600.0
# commission_pct             NaN
# manager_id               114.0
# department_id               30
# Name: Guy, dtype: object

# %%
emps.loc["Alexander"]
# Out:
#             employee_id last_name    email  phone_number   hire_date  \
# first_name
# Alexander           103    Hunold  AHUNOLD  590.423.4567  1990-01-03
# Alexander           115      Khoo    AKHOO  515.127.4562  1995-05-18
#
#               job_id  salary  commission_pct  manager_id  department_id
# first_name
# Alexander    IT_PROG  9000.0             NaN       102.0             60
# Alexander   PU_CLERK  3100.0             NaN       114.0             30

# %%
emps.reset_index()
# Out:
#    first_name  employee_id   last_name     email  phone_number   hire_date  \
# 0   Alexander          103      Hunold   AHUNOLD  590.423.4567  1990-01-03
# 1   Alexander          115        Khoo     AKHOO  515.127.4562  1995-05-18
# 2       Bruce          104       Ernst    BERNST  590.423.4568  1991-05-21
# 3       David          105      Austin   DAUSTIN  590.423.4569  1997-06-25
# 4         Den          114    Raphaely  DRAPHEAL  515.127.4561  1994-12-07
# 5       Diana          107     Lorentz  DLORENTZ  590.423.5567  1999-02-07
# 6         Guy          118      Himuro   GHIMURO  515.127.4565  1998-11-15
# 7       Karen          119  Colmenares  KCOLMENA  515.127.4566  1999-08-10
# 8         Lex          102     De Haan   LDEHAAN  515.123.4569  1993-01-13
# 9       Neena          101     Kochhar  NKOCHHAR  515.123.4568  1989-09-21
# 10     Shelli          116       Baida    SBAIDA  515.127.4563  1997-12-24
# ...

# %%
emps.duplicated("last_name").sum()
# Out:
# 0

# %%
emps.set_index('last_name', inplace = True)

# %%
emps.sort_index(inplace = True)

# %%
# מה התוית של שורה 0
emps.iloc[0].name
# Out:
# 'Austin'

# %%
# מה המיקום של תוית ידועה למשל של קינג
emps.index.get_loc('King')
# Out:
# 8

# %%
emps.iloc[8]
# Out:
# employee_id                100
# email                    SKING
# phone_number      515.123.4567
# hire_date           1987-06-17
# job_id                 AD_PRES
# salary                 24000.0
# commission_pct             NaN
# manager_id                 NaN
# department_id               90
# Name: King, dtype: object
