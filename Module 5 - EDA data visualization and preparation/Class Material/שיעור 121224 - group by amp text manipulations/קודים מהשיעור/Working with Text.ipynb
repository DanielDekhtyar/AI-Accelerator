# %%
x = 'tRa lA La'
x.lower()
# Out:
# 'tra la la'

# %%
x.upper()
# Out:
# 'TRA LA LA'

# %%
x.title()
# Out:
# 'Tra La La'

# %%
x.capitalize()
# Out:
# 'Tra la la'

# %%
import pandas as pd

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   object
#  6   reading score                1000 non-null   object
#  7   writing score                1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education          lunch  \
# 0  FEMALE        group B           bachelor's degree       standard
# 1  FEMALE        group C                some college       standard
# 2  FEMALE        group B             master's degree       standard
# 3    MALE        group A          associate's degree   free/reduced
# 4    MALE        group C                some college       standard
#
#   test preparation course math score reading score writing score
# 0                    NONE        72%           72%           74%
# 1               COMPLETED        69%           90%           88%
# 2                    NONE        90%           95%           93%
# 3                    NONE        47%           57%           44%
# 4                    NONE        76%           78%           75%

# %%
df["gender"].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9356\3598683929.py in <module>
# ----> 1 df["gender"].lower()
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
df["gender"].str.lower()
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"].str.lower().str.capitalize()
# Out:
# 0      Female
# 1      Female
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995    Female
# 996      Male
# 997    Female
# 998    Female
# 999    Female
# Name: gender, Length: 1000, dtype: object

# %%
df["gender"] =  df["gender"].str.lower()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education          lunch  \
# 0  female        group B           bachelor's degree       standard
# 1  female        group C                some college       standard
# 2  female        group B             master's degree       standard
# 3    male        group A          associate's degree   free/reduced
# 4    male        group C                some college       standard
#
#   test preparation course math score reading score writing score
# 0                    NONE        72%           72%           74%
# 1               COMPLETED        69%           90%           88%
# 2                    NONE        90%           95%           93%
# 3                    NONE        47%           57%           44%
# 4                    NONE        76%           78%           75%

# %%
len(x)
# Out:
# 9

# %%
df['parental level of education'].str.len()
# Out:
# 0      17
# 1      12
# 2      15
# 3      18
# 4      12
#        ..
# 995    15
# 996    11
# 997    11
# 998    12
# 999    12
# Name: parental level of education, Length: 1000, dtype: int64

# %%
len(df['parental level of education'])
# Out:
# 1000

# %%
x
# Out:
# 'tRa lA La'

# %%
x.replace("a", '@')
# Out:
# 'tR@ lA L@'

# %%
x.replace(' ','')
# Out:
# 'tRalALa'

# %%
df["math score"].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9356\4014902019.py in <module>
# ----> 1 df["math score"].astype('int')
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\.conda\envs\env_2\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df["math score"].str.replace('%', '')
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: object

# %%
df["math score"] = df["math score"].str.replace('%', '').astype(int)

# %%
df
# Out:
#      gender race/ethnicity parental level of education          lunch  \
# 0    female        group B           bachelor's degree       standard
# 1    female        group C                some college       standard
# 2    female        group B             master's degree       standard
# 3      male        group A          associate's degree   free/reduced
# 4      male        group C                some college       standard
# ..      ...            ...                         ...            ...
# 995  female        group E             master's degree       standard
# 996    male        group C                 high school   free/reduced
# 997  female        group C                 high school   free/reduced
# 998  female        group D                some college       standard
# 999  female        group D                some college   free/reduced
#
#     test preparation course  math score reading score writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int32
#  6   reading score                1000 non-null   object
#  7   writing score                1000 non-null   object
# dtypes: int32(1), object(7)
# memory usage: 58.7+ KB

# %%
col_list = ['reading score','writing score']

# %%
#df[col_list] = df[col_list].str.replace('%', '').astype('int')

# %%
mask = df["parental level of education"].str.contains('degree')

# %%
df[mask]
# Out:
#      gender race/ethnicity parental level of education          lunch  \
# 0    female        group B           bachelor's degree       standard
# 2    female        group B             master's degree       standard
# 3      male        group A          associate's degree   free/reduced
# 5    female        group B          associate's degree       standard
# 10     male        group C          associate's degree       standard
# ..      ...            ...                         ...            ...
# 979  female        group C          associate's degree       standard
# 986  female        group C          associate's degree       standard
# 992  female        group D          associate's degree   free/reduced
# 993  female        group D           bachelor's degree   free/reduced
# 995  female        group E             master's degree       standard
#
#     test preparation course  math score reading score writing score
# ...

# %%
mask = df["parental level of education"].str.contains('degree', df2

# %%
df[mask]
# Out:
#      gender race/ethnicity parental level of education          lunch  \
# 0    female        group B           bachelor's degree       standard
# 2    female        group B             master's degree       standard
# 3      male        group A          associate's degree   free/reduced
# 5    female        group B          associate's degree       standard
# 10     male        group C          associate's degree       standard
# ..      ...            ...                         ...            ...
# 979  female        group C          associate's degree       standard
# 986  female        group C          associate's degree       standard
# 992  female        group D          associate's degree   free/reduced
# 993  female        group D           bachelor's degree   free/reduced
# 995  female        group E             master's degree       standard
#
#     test preparation course  math score reading score writing score
# ...

# %%
df2 = pd.read_csv('StudentsPerfomrance_whitespace.csv')

# %%
df2
# Out:
#          gender race/ethnicity parental level of education              lunch  \
# 0       female         group B           bachelor's degree          standard
# 1       female         group C                some college          standard
# 2       female         group B             master's degree          standard
# 3         male         group A          associate's degree      free/reduced
# 4         male         group C                some college          standard
# ..          ...            ...                         ...                ...
# 995     female         group E             master's degree          standard
# 996       male         group C                 high school      free/reduced
# 997     female         group C                 high school      free/reduced
# 998     female         group D                some college          standard
# 999     female         group D                some college      free/reduced
#
# ...

# %%
"   exa  mp  le   ".strip()
# Out:
# 'exa  mp  le'

# %%
"   exa  mp  le   ".lstrip()
# Out:
# 'exa  mp  le   '

# %%
"   exa  mp  le   ".rstrip()
# Out:
# '   exa  mp  le'

# %%
df2["gender"].str.len()
# Out:
# 0      10
# 1      10
# 2      10
# 3       8
# 4       8
#        ..
# 995    10
# 996     8
# 997    10
# 998    10
# 999    10
# Name: gender, Length: 1000, dtype: int64

# %%
df2["gender"].str.strip().str.len()
# Out:
# 0      6
# 1      6
# 2      6
# 3      4
# 4      4
#       ..
# 995    6
# 996    4
# 997    6
# 998    6
# 999    6
# Name: gender, Length: 1000, dtype: int64

# %%
df2["gender"] = df2["gender"].str.strip()

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education              lunch  \
# 0  female        group B           bachelor's degree          standard
# 1  female        group C                some college          standard
# 2  female        group B             master's degree          standard
# 3    male        group A          associate's degree      free/reduced
# 4    male        group C                some college          standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
cereal = pd.read_csv('cereal.csv',index_col ='name' )

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.6+ KB

# %%
cereal.sort_index(inplace = True)

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
type(cereal.index)
# Out:
# pandas.core.indexes.base.Index

# %%
cereal.index
# Out:
# Index(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', 'Cap'n'Crunch', 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', 'Cracklin' Oat Bran', 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats',
#        'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran',
#        'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams', 'Grape Nuts Flakes',
#        'Grape-Nuts', 'Great Grains Pecan', 'Honey Graham Ohs',
#        'Honey Nut Cheerios', 'Honey-comb', 'Just Right Crunchy  Nuggets',
#        'Just Right Fruit & Nut', 'Kix', 'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins; Dates; & Almonds', 'Muesli Raisins; Peaches; & Pecans',
# ...

# %%
cereal.index.str.upper()
# Out:
# Index(['100% BRAN', '100% NATURAL BRAN', 'ALL-BRAN',
#        'ALL-BRAN WITH EXTRA FIBER', 'ALMOND DELIGHT',
#        'APPLE CINNAMON CHEERIOS', 'APPLE JACKS', 'BASIC 4', 'BRAN CHEX',
#        'BRAN FLAKES', 'CAP'N'CRUNCH', 'CHEERIOS', 'CINNAMON TOAST CRUNCH',
#        'CLUSTERS', 'COCOA PUFFS', 'CORN CHEX', 'CORN FLAKES', 'CORN POPS',
#        'COUNT CHOCULA', 'CRACKLIN' OAT BRAN', 'CREAM OF WHEAT (QUICK)',
#        'CRISPIX', 'CRISPY WHEAT & RAISINS', 'DOUBLE CHEX', 'FROOT LOOPS',
#        'FROSTED FLAKES', 'FROSTED MINI-WHEATS',
#        'FRUIT & FIBRE DATES; WALNUTS; AND OATS', 'FRUITFUL BRAN',
#        'FRUITY PEBBLES', 'GOLDEN CRISP', 'GOLDEN GRAHAMS', 'GRAPE NUTS FLAKES',
#        'GRAPE-NUTS', 'GREAT GRAINS PECAN', 'HONEY GRAHAM OHS',
#        'HONEY NUT CHEERIOS', 'HONEY-COMB', 'JUST RIGHT CRUNCHY  NUGGETS',
#        'JUST RIGHT FRUIT & NUT', 'KIX', 'LIFE', 'LUCKY CHARMS', 'MAYPO',
#        'MUESLI RAISINS; DATES; & ALMONDS', 'MUESLI RAISINS; PEACHES; & PECANS',
# ...

# %%
cereal.index
# Out:
# Index(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', 'Cap'n'Crunch', 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', 'Cracklin' Oat Bran', 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats',
#        'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran',
#        'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams', 'Grape Nuts Flakes',
#        'Grape-Nuts', 'Great Grains Pecan', 'Honey Graham Ohs',
#        'Honey Nut Cheerios', 'Honey-comb', 'Just Right Crunchy  Nuggets',
#        'Just Right Fruit & Nut', 'Kix', 'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins; Dates; & Almonds', 'Muesli Raisins; Peaches; & Pecans',
# ...

# %%
cereal.columns = cereal.columns.str.upper()

# %%
cereal.head()
# Out:
#                           MFR TYPE  CALORIES  PROTEIN  FAT  SODIUM  FIBER  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            CARBO  SUGARS  POTASS  VITAMINS  SHELF  WEIGHT  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            CUPS     RATING
# name
# ...

# %%
"This is a string".split()
# Out:
# ['This', 'is', 'a', 'string']

# %%
emps = pd.read_csv ('employee_fullnames.csv')

# %%
emps
# Out:
#               full name  salary  start_date       gender  remote  \
# 0    Haleigh Calderhead  334473    05-09-20          NaN    True
# 1        Coretta McEvon  637457   3/20/2020         Male   False
# 2      Clarette Tarbett  977749  11/22/2020      Agender    True
# 3      Jaime Gianneschi  253523    09-02-20     Bigender   False
# 4         Ediva Skelton  325185    02-04-20       Female    True
# ..                  ...     ...         ...          ...     ...
# 995   Ysabel Stollmeyer  649625  10/18/2020   Polygender   False
# 996    Ashby Threadgold  140806  12/28/2020  Genderfluid   False
# 997     Justino Asquith  950280  10/26/2020  Genderqueer   False
# 998      Jerald Penella  862555    09-08-20       Female   False
# 999         Aubrie Hunt  549364   3/29/2020   Polygender   False
#
#                team
# 0        management
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# ..              ...
# 995      management
# ...

# %%
emps["full name"].str.split(" ")
# Out:
# 0      [Haleigh, Calderhead]
# 1          [Coretta, McEvon]
# 2        [Clarette, Tarbett]
# 3        [Jaime, Gianneschi]
# 4           [Ediva, Skelton]
#                ...
# 995     [Ysabel, Stollmeyer]
# 996      [Ashby, Threadgold]
# 997       [Justino, Asquith]
# 998        [Jerald, Penella]
# 999           [Aubrie, Hunt]
# Name: full name, Length: 1000, dtype: object

# %%
emps["full name"].str.split(" ").str.get(0)
# Out:
# 0       Haleigh
# 1       Coretta
# 2      Clarette
# 3         Jaime
# 4         Ediva
#          ...
# 995      Ysabel
# 996       Ashby
# 997     Justino
# 998      Jerald
# 999      Aubrie
# Name: full name, Length: 1000, dtype: object

# %%
emps["full name"].str.split(" ").str.get(1)
# Out:
# 0      Calderhead
# 1          McEvon
# 2         Tarbett
# 3      Gianneschi
# 4         Skelton
#           ...
# 995    Stollmeyer
# 996    Threadgold
# 997       Asquith
# 998       Penella
# 999          Hunt
# Name: full name, Length: 1000, dtype: object

# %%
emps["full name"].str.split(" ").str.get(0).value_counts()
# Out:
# Clarinda    3
# Wilma       3
# Corrina     2
# Graham      2
# Esra        2
#            ..
# Rikki       1
# Rriocard    1
# Cybill      1
# Doe         1
# Aubrie      1
# Name: full name, Length: 941, dtype: int64

# %%
emps["full name"].str.split (" ", n=1,expand = True)
# Out:
#             0           1
# 0     Haleigh  Calderhead
# 1     Coretta      McEvon
# 2    Clarette     Tarbett
# 3       Jaime  Gianneschi
# 4       Ediva     Skelton
# ..        ...         ...
# 995    Ysabel  Stollmeyer
# 996     Ashby  Threadgold
# 997   Justino     Asquith
# 998    Jerald     Penella
# 999    Aubrie        Hunt
#
# [1000 rows x 2 columns]

# %%
emps[['first_name', 'last_name']] = emps["full name"].str.split (" ", n=1,expand = True)

# %%
emps
# Out:
#               full name  salary  start_date       gender  remote  \
# 0    Haleigh Calderhead  334473    05-09-20          NaN    True
# 1        Coretta McEvon  637457   3/20/2020         Male   False
# 2      Clarette Tarbett  977749  11/22/2020      Agender    True
# 3      Jaime Gianneschi  253523    09-02-20     Bigender   False
# 4         Ediva Skelton  325185    02-04-20       Female    True
# ..                  ...     ...         ...          ...     ...
# 995   Ysabel Stollmeyer  649625  10/18/2020   Polygender   False
# 996    Ashby Threadgold  140806  12/28/2020  Genderfluid   False
# 997     Justino Asquith  950280  10/26/2020  Genderqueer   False
# 998      Jerald Penella  862555    09-08-20       Female   False
# 999         Aubrie Hunt  549364   3/29/2020   Polygender   False
#
#                team first_name   last_name
# 0        management    Haleigh  Calderhead
# 1       engineering    Coretta      McEvon
# 2       engineering   Clarette     Tarbett
# ...

# %%
emps.drop ("full name", axis =1,  inplace = True)

# %%
emps
# Out:
#      salary  start_date       gender  remote            team first_name  \
# 0    334473    05-09-20          NaN    True      management    Haleigh
# 1    637457   3/20/2020         Male   False     engineering    Coretta
# 2    977749  11/22/2020      Agender    True     engineering   Clarette
# 3    253523    09-02-20     Bigender   False       marketing      Jaime
# 4    325185    02-04-20       Female    True       marketing      Ediva
# ..      ...         ...          ...     ...             ...        ...
# 995  649625  10/18/2020   Polygender   False      management     Ysabel
# 996  140806  12/28/2020  Genderfluid   False      management      Ashby
# 997  950280  10/26/2020  Genderqueer   False      management    Justino
# 998  862555    09-08-20       Female   False     engineering     Jerald
# 999  549364   3/29/2020   Polygender   False  data analytics     Aubrie
#
#       last_name
# 0    Calderhead
# 1        McEvon
# 2       Tarbett
# 3    Gianneschi
# ...
