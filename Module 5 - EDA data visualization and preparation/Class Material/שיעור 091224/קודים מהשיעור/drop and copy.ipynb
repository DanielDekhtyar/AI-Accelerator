# %%
import pandas as pd

cereal = pd.read_csv('cereal.csv', index_col = "name")
cereal.sort_index(inplace = True)

# %%
cereal.head(10)
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# Apple Jacks                 K    C       110        2    0     125    1.0
# Basic 4                     G    C       130        3    2     210    2.0
# Bran Chex                   R    C        90        2    1     200    4.0
# Bran Flakes                 P    C        90        3    0     210    5.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# ...

# %%
my_rating = cereal['rating']

# %%
my_rating
# Out:
# name
# 100% Bran                    68.402973
# 100% Natural Bran            33.983679
# All-Bran                     59.425505
# All-Bran with Extra Fiber    93.704912
# Almond Delight               34.384843
#                                ...
# Triples                      39.106174
# Trix                         27.753301
# Wheat Chex                   49.787445
# Wheaties                     51.592193
# Wheaties Honey Gold          36.187559
# Name: rating, Length: 77, dtype: float64

# %%
my_rating["All-Bran"]
# Out:
# 59.425505

# %%
my_rating["All-Bran"] =100.0
# Out:
# C:\Users\AiFTW\.conda\envs\env_2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
my_rating["All-Bran"]
# Out:
# 100.0

# %%
cereal.head(10)
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# Apple Jacks                 K    C       110        2    0     125    1.0
# Basic 4                     G    C       130        3    2     210    2.0
# Bran Chex                   R    C        90        2    1     200    4.0
# Bran Flakes                 P    C        90        3    0     210    5.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# ...

# %%
my_copy = cereal['rating'].copy()

# %%
my_copy
# Out:
# name
# 100% Bran                     68.402973
# 100% Natural Bran             33.983679
# All-Bran                     100.000000
# All-Bran with Extra Fiber     93.704912
# Almond Delight                34.384843
#                                 ...
# Triples                       39.106174
# Trix                          27.753301
# Wheat Chex                    49.787445
# Wheaties                      51.592193
# Wheaties Honey Gold           36.187559
# Name: rating, Length: 77, dtype: float64

# %%
my_copy["Trix"]= 110.0

# %%
my_copy
# Out:
# name
# 100% Bran                     68.402973
# 100% Natural Bran             33.983679
# All-Bran                     100.000000
# All-Bran with Extra Fiber     93.704912
# Almond Delight                34.384843
#                                 ...
# Triples                       39.106174
# Trix                         110.000000
# Wheat Chex                    49.787445
# Wheaties                      51.592193
# Wheaties Honey Gold           36.187559
# Name: rating, Length: 77, dtype: float64

# %%
cereal.tail(10)
# Out:
#                         mfr type  calories  protein  fat  sodium  fiber  \
# name
# Special K                 K    C       110        6    0     230    1.0
# Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# Total Corn Flakes         G    C       110        2    1     200    0.0
# Total Raisin Bran         G    C       140        3    1     190    4.0
# Total Whole Grain         G    C       100        3    1     200    3.0
# Triples                   G    C       110        2    1     250    0.0
# Trix                      G    C       110        1    1     140    0.0
# Wheat Chex                R    C       100        3    1     230    3.0
# Wheaties                  G    C       100        3    1     200    3.0
# Wheaties Honey Gold       G    C       110        2    1     200    1.0
#
#                          carbo  sugars  potass  vitamins  shelf  weight  cups  \
# name
# Special K                 16.0       3      55        25      1     1.0  1.00
# ...

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups      rating
# name
# ...

# %%
cereal.drop("All-Bran", inplace =True)

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# Apple Cinnamon Cheerios     10.5      10      70        25      1     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.drop(["Triples", "Trix"])
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios     G    C       110        2    2     180    1.5
# ...                        ..  ...       ...      ...  ...     ...    ...
# Total Raisin Bran           G    C       140        3    1     190    4.0
# Total Whole Grain           G    C       100        3    1     200    3.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
cereal.drop("mfr", axis = 1, inplace = True)

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      76 non-null     object
#  1   calories  76 non-null     int64
#  2   protein   76 non-null     int64
#  3   fat       76 non-null     int64
#  4   sodium    76 non-null     int64
#  5   fiber     76 non-null     float64
#  6   carbo     76 non-null     float64
#  7   sugars    76 non-null     int64
#  8   potass    76 non-null     int64
#  9   vitamins  76 non-null     int64
#  10  shelf     76 non-null     int64
#  11  weight    76 non-null     float64
#  12  cups      76 non-null     float64
#  13  rating    76 non-null     float64
# dtypes: float64(5), int64(8), object(1)
# memory usage: 11.0+ KB

# %%
del cereal["calories"]

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      76 non-null     object
#  1   protein   76 non-null     int64
#  2   fat       76 non-null     int64
#  3   sodium    76 non-null     int64
#  4   fiber     76 non-null     float64
#  5   carbo     76 non-null     float64
#  6   sugars    76 non-null     int64
#  7   potass    76 non-null     int64
#  8   vitamins  76 non-null     int64
#  9   shelf     76 non-null     int64
#  10  weight    76 non-null     float64
#  11  cups      76 non-null     float64
#  12  rating    76 non-null     float64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 10.4+ KB
