# %%
# conda install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#יצירת חיבור
engine = create_engine('postgresql://postgres:sql@localhost:5432/oracle')
#  create_engine('סוג מסד נתונים://pשם משתמשs:sסיסמאl@lשרתt:port/oסט הנתוניםe')

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine)

# %%
df.head()
# Out:
#    department_id  department_name  manager_id  location_id
# 0             10   Administration       200.0         1700
# 1             20        Marketing       201.0         1800
# 2             30       Purchasing       114.0         1700
# 3             40  Human Resources       203.0         2400
# 4             50         Shipping       121.0         1500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_id    27 non-null     int64
#  1   department_name  27 non-null     object
#  2   manager_id       11 non-null     float64
#  3   location_id      27 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 996.0+ bytes

# %%
#גישה עם משתנה
query = 'SELECT e.last_name, d.department_name FROM employees e JOIN departments d USING (department_id)'
df2 = pd.read_sql(query, con = engine)

# %%
df2.head(3)
# Out:
#   last_name department_name
# 0      King       Executive
# 1   Kochhar       Executive
# 2   De Haan       Executive

# %%
df3  = pd.read_sql('SELECT * FROM my_df', con = engine)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    76 non-null     object
#  1   dept    76 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
df3['whatever']= 100

# %%
df3
# Out:
#                 name              dept  whatever
# 0        King Steven         Executive       100
# 1      Kochhar Neena         Executive       100
# 2        De Haan Lex         Executive       100
# 3   Hunold Alexander                IT       100
# 4        Ernst Bruce                IT       100
# ..               ...               ...       ...
# 71           Fay Pat         Marketing       100
# 72      Mavris Susan   Human Resources       100
# 73      Baer Hermann  Public Relations       100
# 74   Higgins Shelley        Accounting       100
# 75     Gietz William        Accounting       100
#
# [76 rows x 3 columns]

# %%
#conda intall psycopg2 #בעיקר רלוונטי לכיתה

# %%
import psycopg2

# %%
conection = psycopg2.connect (
    dbname = "oracle", #שם סט הנתונים
    user = "postgres", #משתמש
    password = 'sql', #סיסמא
    host = 'localhost', #שרת
    port = 5432
)

# %%
df = pd.read_sql('SELECT * FROM my_df', con =conection )
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13196\4236132785.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM my_df', con =conection )

# %%
df.head()
# Out:
#                name       dept
# 0       King Steven  Executive
# 1     Kochhar Neena  Executive
# 2       De Haan Lex  Executive
# 3  Hunold Alexander         IT
# 4       Ernst Bruce         IT

# %%
#לסגור את השיחה
conection.close()

# %%
# מה הלאה iddex
df = pd.read_sql('SELECT * FROM departments', con = engine)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_id    27 non-null     int64
#  1   department_name  27 non-null     object
#  2   manager_id       11 non-null     float64
#  3   location_id      27 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 996.0+ bytes

# %%
df
# Out:
#     department_id       department_name  manager_id  location_id
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
#שינוי בדיעבד
df.set_index(keys = 'department_id',inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 10 to 270
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_name  27 non-null     object
#  1   manager_id       11 non-null     float64
#  2   location_id      27 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 864.0+ bytes

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine, index_col = 'department_id')

# %%
df
# Out:
#                     department_name  manager_id  location_id
# department_id
# 10                   Administration       200.0         1700
# 20                        Marketing       201.0         1800
# 30                       Purchasing       114.0         1700
# 40                  Human Resources       203.0         2400
# 50                         Shipping       121.0         1500
# 60                               IT       103.0         1400
# 70                 Public Relations       204.0         2700
# 80                            Sales       145.0         2500
# 90                        Executive       100.0         1700
# 100                         Finance       108.0         1700
# 110                      Accounting       205.0         1700
# 120                        Treasury         NaN         1700
# 130                   Corporate Tax         NaN         1700
# 140              Control And Credit         NaN         1700
# ...

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine)

# %%
df.set_index(keys= 'department_id', append = True) #no inplace True
# Out:
#                        department_name  manager_id  location_id
#    department_id
# 0  10                   Administration       200.0         1700
# 1  20                        Marketing       201.0         1800
# 2  30                       Purchasing       114.0         1700
# 3  40                  Human Resources       203.0         2400
# 4  50                         Shipping       121.0         1500
# 5  60                               IT       103.0         1400
# 6  70                 Public Relations       204.0         2700
# 7  80                            Sales       145.0         2500
# 8  90                        Executive       100.0         1700
# 9  100                         Finance       108.0         1700
# 10 110                      Accounting       205.0         1700
# 11 120                        Treasury         NaN         1700
# 12 130                   Corporate Tax         NaN         1700
# ...

# %%
df.set_index(keys= 'department_id', inplace = True)

# %%
df.head(1)
# Out:
#               department_name  manager_id  location_id
# department_id
# 10             Administration       200.0         1700

# %%
df.reset_index(drop = True)  #no inplace True
# Out:
#          department_name  manager_id  location_id
# 0         Administration       200.0         1700
# 1              Marketing       201.0         1800
# 2             Purchasing       114.0         1700
# 3        Human Resources       203.0         2400
# 4               Shipping       121.0         1500
# 5                     IT       103.0         1400
# 6       Public Relations       204.0         2700
# 7                  Sales       145.0         2500
# 8              Executive       100.0         1700
# 9                Finance       108.0         1700
# 10            Accounting       205.0         1700
# 11              Treasury         NaN         1700
# 12         Corporate Tax         NaN         1700
# 13    Control And Credit         NaN         1700
# 14  Shareholder Services         NaN         1700
# 15              Benefits         NaN         1700
# 16         Manufacturing         NaN         1700
# 17          Construction         NaN         1700
# ...

# %%
df.reset_index(inplace= True)

# %%
df.head(1)
# Out:
#    department_id department_name  manager_id  location_id
# 0             10  Administration       200.0         1700

# %%
#to csv
df.to_csv('my_csv.csv')

df= pd.read_csv('my_csv.csv')

# %%
df
# Out:
#     Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  department_id  \
# 0              0             0             0           0             10
# 1              1             1             1           1             20
# 2              2             2             2           2             30
# 3              3             3             3           3             40
# 4              4             4             4           4             50
# 5              5             5             5           5             60
# 6              6             6             6           6             70
# 7              7             7             7           7             80
# 8              8             8             8           8             90
# 9              9             9             9           9            100
# 10            10            10            10          10            110
# 11            11            11            11          11            120
# ...

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine, 
                index_col = 'department_id')

# %%
df.head(1)
# Out:
#               department_name  manager_id  location_id
# department_id
# 10             Administration       200.0         1700

# %%
df.to_csv('my_csv.csv',index = False)

# %%
df = pd.read_csv('my_csv.csv')

# %%
df.head(1)
# Out:
#   department_name  manager_id  location_id
# 0  Administration       200.0         1700

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine)
df.to_csv('my_csv.csv',index = False)
df = pd.read_csv('my_csv.csv')
df.head(1)
# Out:
#    department_id department_name  manager_id  location_id
# 0             10  Administration       200.0         1700

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine)
df.head(1)
# Out:
#    department_id department_name  manager_id  location_id
# 0             10  Administration       200.0         1700

# %%
df.to_csv('my_csv.csv')

# %%
df = pd.read_csv('my_csv.csv', index_col = 'department_id')

# %%
df.head(1)
# Out:
#                Unnamed: 0 department_name  manager_id  location_id
# department_id
# 10                      0  Administration       200.0         1700

# %%
df = pd.read_sql('SELECT * FROM departments', con = engine)
df.head(3)
# Out:
#    department_id department_name  manager_id  location_id
# 0             10  Administration       200.0         1700
# 1             20       Marketing       201.0         1800
# 2             30      Purchasing       114.0         1700

# %%
df.to_csv('my_csv.csv', index = False)
df = pd.read_csv('my_csv.csv', index_col = 'department_id')
df.head(1)
# Out:
#               department_name  manager_id  location_id
# department_id
# 10             Administration       200.0         1700

# %%
#export
df.to_csv('btc_usd.csv')
#import
df = pd.read_csv('btc_usd.csv', index_col = 'btc_dates')
