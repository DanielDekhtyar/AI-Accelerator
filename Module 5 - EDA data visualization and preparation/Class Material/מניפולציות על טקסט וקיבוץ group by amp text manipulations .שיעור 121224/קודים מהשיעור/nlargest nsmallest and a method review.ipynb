# %%
import pandas as pd

# %%
cereal = pd.read_csv('cereal.csv', index_col = 'name')

cereal.sort_index(inplace = True)

# %%
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.6+ KB

# %%
cereal[['calories']].query('calories  > 140')
# Out:
#                                    calories
# name
# Muesli Raisins; Dates; & Almonds        150
# Muesli Raisins; Peaches; & Pecans       150
# Mueslix Crispy Blend                    160

# %%
mask = cereal['calories'] >100

# %%
cereal.where(mask, 'too fattning')
# Out:
#                                     mfr          type      calories  \
# name
# 100% Bran                  too fattning  too fattning  too fattning
# 100% Natural Bran                     Q             C           120
# All-Bran                   too fattning  too fattning  too fattning
# All-Bran with Extra Fiber  too fattning  too fattning  too fattning
# Almond Delight                        R             C           110
# ...                                 ...           ...           ...
# Triples                               G             C           110
# Trix                                  G             C           110
# Wheat Chex                 too fattning  too fattning  too fattning
# Wheaties                   too fattning  too fattning  too fattning
# Wheaties Honey Gold                   G             C           110
#
#                                 protein           fat        sodium  \
# name
# ...

# %%
cereal['calories'].where(mask, 'too fattning')
# Out:
# name
# 100% Bran                    too fattning
# 100% Natural Bran                     120
# All-Bran                     too fattning
# All-Bran with Extra Fiber    too fattning
# Almond Delight                        110
#                                  ...
# Triples                               110
# Trix                                  110
# Wheat Chex                   too fattning
# Wheaties                     too fattning
# Wheaties Honey Gold                   110
# Name: calories, Length: 77, dtype: object

# %%
cereal['calories'] = cereal['calories'].where(mask, 'too fattning')

# %%
cereal
# Out:
#                           mfr type      calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C  too fattning        4    1     130   10.0
# 100% Natural Bran           Q    C           120        3    5      15    2.0
# All-Bran                    K    C  too fattning        4    1     260    9.0
# All-Bran with Extra Fiber   K    C  too fattning        4    0     140   14.0
# Almond Delight              R    C           110        2    2     200    1.0
# ...                        ..  ...           ...      ...  ...     ...    ...
# Triples                     G    C           110        2    1     250    0.0
# Trix                        G    C           110        1    1     140    0.0
# Wheat Chex                  R    C  too fattning        3    1     230    3.0
# Wheaties                    G    C  too fattning        3    1     200    3.0
# Wheaties Honey Gold         G    C           110        2    1     200    1.0
#
# ...

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     object
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 11.7+ KB

# %%
#top rating
cereal.sort_values('rating', ascending = False).head(3)
# Out:
#                           mfr type      calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C  too fattning        4    0     140   14.0
# Shredded Wheat 'n'Bran      N    C  too fattning        3    0       0    4.0
# Shredded Wheat spoon size   N    C  too fattning        3    0       0    3.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Shredded Wheat 'n'Bran      19.0       0     140         0      1     1.0
# Shredded Wheat spoon size   20.0       0     120         0      1     1.0
#
#                            cups     rating
# name
# All-Bran with Extra Fiber  0.50  93.704912
# Shredded Wheat 'n'Bran     0.67  74.472949
# Shredded Wheat spoon size  0.67  72.801787

# %%
cereal.nlargest(3, "rating")
# Out:
#                           mfr type      calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C  too fattning        4    0     140   14.0
# Shredded Wheat 'n'Bran      N    C  too fattning        3    0       0    4.0
# Shredded Wheat spoon size   N    C  too fattning        3    0       0    3.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Shredded Wheat 'n'Bran      19.0       0     140         0      1     1.0
# Shredded Wheat spoon size   20.0       0     120         0      1     1.0
#
#                            cups     rating
# name
# All-Bran with Extra Fiber  0.50  93.704912
# Shredded Wheat 'n'Bran     0.67  74.472949
# Shredded Wheat spoon size  0.67  72.801787

# %%
cereal.nsmallest(3, "rating")
# Out:
#                       mfr type calories  protein  fat  sodium  fiber  carbo  \
# name
# Cap'n'Crunch            Q    C      120        1    2     220    0.0   12.0
# Cinnamon Toast Crunch   G    C      120        1    3     210    0.0   13.0
# Honey Graham Ohs        Q    C      120        1    2     220    1.0   12.0
#
#                        sugars  potass  vitamins  shelf  weight  cups  \
# name
# Cap'n'Crunch               12      35        25      2     1.0  0.75
# Cinnamon Toast Crunch       9      45        25      2     1.0  0.75
# Honey Graham Ohs           11      45        25      2     1.0  1.00
#
#                           rating
# name
# Cap'n'Crunch           18.042851
# Cinnamon Toast Crunch  19.823573
# Honey Graham Ohs       21.871292
