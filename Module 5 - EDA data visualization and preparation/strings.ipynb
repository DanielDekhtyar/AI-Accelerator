# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielDekhtyar/AI-Accelerator/blob/main/Module%205%20-%20EDA%20data%20visualization%20and%20preparation/strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### תרגיל עבודה עם מחרוזות
# בתרגיל זה תעבדו עם  imdb_top_1000.csv

# %%
import pandas as pd

# %%
imdb = pd.read_csv('imdb_top_1000.csv')

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# **חלק ראשון - הכרות עם מתודות**
# 1.  הציגו את שמות הבמאים באותיות קטנות
# 2.  הציגו את שמות העמודות באותיות גדולות (בסוף, אם ישאר זמן שמרו את השינוי)

# %%
imdb.Director.str.lower()
# Out:
# 0            frank darabont
# 1      francis ford coppola
# 2         christopher nolan
# 3      francis ford coppola
# 4              sidney lumet
#                ...
# 995           blake edwards
# 996          george stevens
# 997          fred zinnemann
# 998        alfred hitchcock
# 999        alfred hitchcock
# Name: Director, Length: 1000, dtype: object

# %%
imdb.columns = imdb.columns.str.upper()

# %%
imdb.head(3)
# Out:
#                                          POSTER_LINK  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                SERIES_TITLE RELEASED_YEAR CERTIFICATE  RUNTIME  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   GENRE  IMDB_RATING  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             OVERVIEW  META_SCORE  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                DIRECTOR           STAR1           STAR2          STAR3  \
# ...

# %% [markdown]
#  **תנאים עם מחרוזות**
#
# 3. הציגו 10 סרטים ראשונים שהמילה the
#    מופיעה בהם
# 4. הציגו רק סרטים שאורך שמם הוא עד 3 תוים כולל
# 5. הציגו סרטים שאורך שמם הוא בין 12 ל20 תוים

# %%
mask_the = imdb["SERIES_TITLE"].str.contains("the")

# %%
imdb[mask_the].head(10)
# Out:
#                                           POSTER_LINK  \
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 17  https://m.media-amazon.com/images/M/MV5BZjA0OW...
# 28  https://m.media-amazon.com/images/M/MV5BNjNhZT...
# 47  https://m.media-amazon.com/images/M/MV5BZmU0M2...
# 48  https://m.media-amazon.com/images/M/MV5BZGI5Mj...
# 58  https://m.media-amazon.com/images/M/MV5BMjMwND...
#
#                                          SERIES_TITLE RELEASED_YEAR  \
# 1                                       The Godfather          1972
# 3                              The Godfather: Part II          1974
# 5       The Lord of the Rings: The Return of the King          2003
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# ...

# %%
mask_len3 = imdb["SERIES_TITLE"].str.len() <=3

# %%
imdb[mask_len3]
# Out:
#                                            POSTER_LINK SERIES_TITLE  \
# 146  https://m.media-amazon.com/images/M/MV5BMTk3ND...           Up
# 172  https://m.media-amazon.com/images/M/MV5BZDBjZT...          Ran
# 207  https://m.media-amazon.com/images/M/MV5BMTYzOT...           PK
# 341  https://m.media-amazon.com/images/M/MV5BMjA1Nz...          Her
# 400  https://m.media-amazon.com/images/M/MV5BYjYyOD...          JFK
# 432  https://m.media-amazon.com/images/M/MV5BMTQ4MT...           8½
# 779  https://m.media-amazon.com/images/M/MV5BMTQxND...          Ray
# 928  https://m.media-amazon.com/images/M/MV5BNWMxYT...          300
# 932  https://m.media-amazon.com/images/M/MV5BMzQ2ZT...          Saw
#
#     RELEASED_YEAR CERTIFICATE  RUNTIME                         GENRE  \
# 146          2009           U   96 min  Animation, Adventure, Comedy
# 172          1985           U  162 min            Action, Drama, War
# 207          2014          UA  153 min        Comedy, Drama, Musical
# ...

# %%
mask_len12to20 = imdb["SERIES_TITLE"].str.len().between(12, 20)

# %%
imdb[mask_len12to20]
# Out:
#                                            POSTER_LINK        SERIES_TITLE  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...       The Godfather
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...     The Dark Knight
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...        12 Angry Men
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...        Pulp Fiction
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...    Schindler's List
# ..                                                 ...                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...        Giù la testa
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...      Kelly's Heroes
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...     The Jungle Book
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...  A Hard Day's Night
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...        The 39 Steps
#
# ...

# %% [markdown]
# **ניקוי נתונים מחרוזתיים**
#
# 6.  הפכו את עמודת gross
#
#     לעמודה מספרית

# %%
imdb.head(2)
# Out:
#                                          POSTER_LINK  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                SERIES_TITLE RELEASED_YEAR CERTIFICATE  RUNTIME         GENRE  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_RATING                                           OVERVIEW  META_SCORE  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                DIRECTOR          STAR1           STAR2       STAR3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             STAR4  NO_OF_VOTES        GROSS
# 0  William Sadler      2343110   28,341,469
# ...

# %%
imdb["GROSS"] = imdb["GROSS"].str.replace(",", "")

# %%
imdb.head(2)
# Out:
#                                          POSTER_LINK  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                SERIES_TITLE RELEASED_YEAR CERTIFICATE  RUNTIME         GENRE  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_RATING                                           OVERVIEW  META_SCORE  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                DIRECTOR          STAR1           STAR2       STAR3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             STAR4  NO_OF_VOTES      GROSS
# 0  William Sadler      2343110   28341469
# ...

# %%
imdb["GROSS"] = imdb["GROSS"].astype('float32')

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   POSTER_LINK    1000 non-null   object
#  1   SERIES_TITLE   1000 non-null   object
#  2   RELEASED_YEAR  1000 non-null   object
#  3   CERTIFICATE    899 non-null    object
#  4   RUNTIME        1000 non-null   object
#  5   GENRE          1000 non-null   object
#  6   IMDB_RATING    1000 non-null   float64
#  7   OVERVIEW       1000 non-null   object
#  8   META_SCORE     843 non-null    float64
#  9   DIRECTOR       1000 non-null   object
#  10  STAR1          1000 non-null   object
#  11  STAR2          1000 non-null   object
#  12  STAR3          1000 non-null   object
#  13  STAR4          1000 non-null   object
#  14  NO_OF_VOTES    1000 non-null   int64
#  15  GROSS          831 non-null    float32
# dtypes: float32(1), float64(2), int64(1), object(12)
# ...

# %%
imdb.head()
# Out:
#                                          POSTER_LINK  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                SERIES_TITLE RELEASED_YEAR CERTIFICATE  RUNTIME  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   GENRE  IMDB_RATING  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# **פיצול עמודות**
#
# 7. צרו העתק של הטבלה הכולל את שם הסרט, שם הבמאי ושם השחקן הראשי
# 8. פצלו את שם השחקן הראשי לשתי עמודות- שם פרטי ושם משפחה

# %%
imdb_new = imdb[['DIRECTOR', 'SERIES_TITLE', 'STAR1']].copy()

# %%
imdb_new
# Out:
#                  DIRECTOR              SERIES_TITLE              STAR1
# 0          Frank Darabont  The Shawshank Redemption        Tim Robbins
# 1    Francis Ford Coppola             The Godfather      Marlon Brando
# 2       Christopher Nolan           The Dark Knight     Christian Bale
# 3    Francis Ford Coppola    The Godfather: Part II          Al Pacino
# 4            Sidney Lumet              12 Angry Men        Henry Fonda
# ..                    ...                       ...                ...
# 995         Blake Edwards    Breakfast at Tiffany's     Audrey Hepburn
# 996        George Stevens                     Giant   Elizabeth Taylor
# 997        Fred Zinnemann     From Here to Eternity     Burt Lancaster
# 998      Alfred Hitchcock                  Lifeboat  Tallulah Bankhead
# 999      Alfred Hitchcock              The 39 Steps       Robert Donat
#
# [1000 rows x 3 columns]

# %%
imdb_new[["First name", "Last name"]] = imdb_new["STAR1"].str.split(" ", n=1, expand=True)

# %%
imdb_new
# Out:
#                  DIRECTOR              SERIES_TITLE              STAR1  \
# 0          Frank Darabont  The Shawshank Redemption        Tim Robbins
# 1    Francis Ford Coppola             The Godfather      Marlon Brando
# 2       Christopher Nolan           The Dark Knight     Christian Bale
# 3    Francis Ford Coppola    The Godfather: Part II          Al Pacino
# 4            Sidney Lumet              12 Angry Men        Henry Fonda
# ..                    ...                       ...                ...
# 995         Blake Edwards    Breakfast at Tiffany's     Audrey Hepburn
# 996        George Stevens                     Giant   Elizabeth Taylor
# 997        Fred Zinnemann     From Here to Eternity     Burt Lancaster
# 998      Alfred Hitchcock                  Lifeboat  Tallulah Bankhead
# 999      Alfred Hitchcock              The 39 Steps       Robert Donat
#
#     First name  Last name
# 0          Tim    Robbins
# 1       Marlon     Brando
# 2    Christian       Bale
# ...
