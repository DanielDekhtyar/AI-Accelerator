# %%
# !pip install pydub
# !apt-get install ffmpeg -y
# !apt-get install -y rubberband-cli
# !pip install pyrubberband

# %%
# !pip install librosa
# #conda install -c conda-forge librosa

# %%
import librosa
import librosa.display
from IPython.display import Audio

import pyrubberband as pyrb # לשינוי קצב
import matplotlib.pyplot as plt
import numpy as np

#import yt_dlp
import os
from pydub import AudioSegment
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# הריצו את הפקודה  בחרו אחת הדוגמאות הזמינות והשמיעו אותה
# ```python
# librosa.util.list_examples()

# %% [markdown]
# רמז- אם הסתבכת למעלה ככה השמענו את ברהמס
# ```python
# file_path = librosa.example('brahms')
# signal, sr = librosa.load(file_path)
# Audio(data=signal, rate=sr)

# %% [markdown]
# מה אורך הקטע שבחרתם בשניות?

# %% [markdown]
# מיינו  3 דוגמאות ששמן מתחיל ב libri1, libri2,libri3 כצליל דיבור של אדם ועוד 3 דוגמאות לבחרתכם כ"אחר"
#
# בנו מודל שילמד להבדיל בין צליל דיבור של אדם לצליל אחר.
