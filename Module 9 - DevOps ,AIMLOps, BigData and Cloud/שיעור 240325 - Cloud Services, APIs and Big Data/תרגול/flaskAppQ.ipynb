# %%
from flask import Flask, request, jsonify
import random

# %% [markdown]
# - כתוב קוד לאפליקציה שמקבלת מספר מהמשתמש ובוחרת מספר שלם רנדומלי בין 1 ל10.
# - אם המשתמש והאפליקציה בחרו את אותו המספר- מדפיסים win
# - אם לא מדפיסים lose
# - חלקים חשובים בקוד:
# ```python
# app = Flask(__name__) #בהתחלה
#
# @app.route('/some_end_point_name')#לפני הגדרת הפונקציה
#
#         your_var = request.args.get('var_name_for_user', type=...)#הגדרת משתנה שהמשתמש ישלח
#         jsonify({"מבנה":"json"})
# if __name__ == '__main__':
#     app.run(debug=True) #בסוף בסוף
